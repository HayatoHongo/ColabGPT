# %% [markdown]
# # **Colabユーザーへの注意**
#
# # **このファイルに直接書き込まないでください—作業が消えることがあります！**
#
# # **必ず作業前にコピーを作成してください。**
#
# コピーの作り方
#
# 1. 左上の「File」をクリック
# > *「File」や「Runtime」などのメニューが見えないときは、右上の“v”マークを押して表示してください。*
#
# 2. 「Save a copy in Drive」を選ぶ
#
# 3. コピーしたファイル名を「YOURNAMEs_FileName.ipynb」に変更する
# > 例：名前がOliviaなら → Olivias_FileName.ipynb
#
#
# ---
#
# * チェックマーク（✅）は保存されません。Chromeのリロードボタンでページを更新すると消えます。<br>
# 途中で止めるときは、テキストセルを追加して「SO FAR DONE」など書いておいてください。
#
# ---
#
# * Colabでは**30分〜90分ごとに以前の出力結果がリセットされます**。<br>
# そのため、`~~ is not defined`のようなエラーが**すごくよく起こります**。
#
# 🔁 `~~ is not defined`エラーが出たらどうする？
#
# 1. まず変数名のスペルを確認してください。<br>
# 2. スペルが正しいのにまだエラーが出るなら、**そのセルをクリックして選択**してください。<br>
# 3. 左上の「Runtime」→「Run before」をクリック。<br>
# → これで**それまでのすべてのセルが再実行されます**。
# 4. 再度、そのセルを実行してください。
#
# もしこれでもエラーが直らなければ、<br>
# 前のセルのTODOの答えに基本的なミスがあるかもしれません。<br>
# 正しいかどうか確認してください。<br>
# またはChatGPTや他のコーディングアシスタントに助けを求めましょう。

# %%
# A Function to Display Tensors Nicely (Feel Free to Skip This)
import torch
import torch.nn as nn
import torch.nn.functional as F

def print_formatted_tensor(*args, width=6, decimals=2):
    """
    A function that neatly formats and displays a PyTorch Tensor, and also prints its size.

    Example usage:
        print_formatted_tensor("name", tensor)
        print_formatted_tensor(tensor)

    Args:
        *args: If given 1 argument, it is treated as a tensor.
               If given 2 arguments, the first is treated as the name, the second as the tensor.
        width (int): Display width for each number (default: 6)
        decimals (int): Number of decimal places to show (default: 2)
    """

    # Determine tensor and name from arguments
    if not args:
        raise ValueError("At least one argument is required.")
    if isinstance(args[0], str):
        if len(args) < 2:
            raise ValueError("Tensor is not specified.")
        name, tensor = args[0], args[1]
    else:
        name, tensor = None, args[0]

    # Convert Tensor to List
    tensor_list = tensor.detach().cpu().tolist()

    def format_list(lst, indent):
        """Formatting a recursively nested list and returning a string"""
        # If the contents are lists, then re-return
        if isinstance(lst, list) and lst and isinstance(lst[0], list):
            inner = ",\n".join(" " * indent + format_list(sub, indent + 2) for sub in lst)
            return "[\n" + inner + "\n" + " " * (indent - 2) + "]"
        # For numerical lists
        return "[" + ", ".join(f"{v:{width}.{decimals}f}" for v in lst) + "]"

    # Formatted string (bar brackets on outermost frames are removed)
    formatted = format_list(tensor_list, indent=9)
    inner_formatted = formatted[1:-1].strip()

    # Result output
    if name:
        print(name)
    print(f"Tensor Size: {list(tensor.size())}")
    print("tensor([")
    print(" " * 9 + inner_formatted)
    print(" " * 7 + "])")

# %% [markdown]
# # **Chapter 18: tiktoken**

# %% [markdown]
# ### **Section 1: tiktokenを使う**

# %% [markdown]
# 大きなデータセットで大きなモデル。
#
# 過学習することなく、順調に訓練誤差も検証誤差も下がっていきました、
#
# しかし、、、！
#
# ---
#
# **遅い！**
#
# ---
#
# もっと訓練を高速化する必要があります。
#
# 一番先に思いつくのはより良いGPUに課金🤑することです。
#
# しかし私には聞こえます、皆さんの声が、、、
#
# 「あんまり課金したくないよー」
#
# そこで、いろいろな高速化のための工夫を加えていくこととなります。
#
# なお、普遍性のないへんてこなテクニックを教えることはありません。
#
# 大規模言語モデルの開発企業でも一般的に行われているplaybook的な高速化の手法しか紹介するつもりはないのでご安心を
#
# そもそも Microsoft, Google, Amazon, Meta, Alibaba のLLMの事前学習モデル開発者にとっても当然計算コストは重要な問題なので。
#
# ただ、基本的にはお金をかければ解決できる問題であるということは忘れないでください。
#
# そのため、10,000ドルの学習コストを5,000ドルに削減するために1日中工夫を考えるのはいいと思うのですが、10ドルのコストを5ドルに減らすために1日中考えるみたいな事はやめましょう。

# %% [markdown]
# どうすればモデルの計算を高速化できるか？
#
# 最も簡単な発想は、**1文字ずつではなく、もっと大きな単位でトークン化する**ことです。
#
# 現代のChatGPTなどのLLMはサブワードごとにトークン化しています。
#
# 以下のサイトにアクセスしてください。
#
# https://platform.openai.com/tokenizer
#
# `show example`を押してみてください。
#
# ちなみに、これからめちゃくちゃ使うことになる`tiktoken`というtokenizerのライブラリは、GPT-3(Legacy)に対応しています。
#
# 英語以外の言語を入力すると「?」が出てきますが、これはUTF-8のバイトにencodeされて、文字として表示できなくなっているだけで、エラーではないので安心してください。

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# このように、ChatGPT をはじめとする現代の大規模言語モデル（LLM）は、
#
# **サブワード単位**でテキストを分割してトークン化しています。
#
# たとえば OpenAI のモデルでは、
#
# * **Open → 11505**
# * **AI → 20185**
#
# というように、文字列が「サブワード」に分かれ、それぞれが数値 ID（トークン）に対応します。
#
# ここでは、**サブワードをどのような仕組みで作っているか（辞書の構築方法）には触れず**、
# まずは **“既にあるトークン化辞書をどう使うか”** に集中して学びます。
#
# サブワード辞書の作り方や、BPE（Byte Pair Encoding）といった内部的な仕組みについては、
# 後の章で詳しく解説していきましょう。

# %% [markdown]
# `tiktoken` は、OpenAI が提供する トークナイザー で、GPTモデルがテキストをどのようにトークン（単語のような単位）に分割するかをシミュレートできます。

# %%
import tiktoken

# %% [markdown]
# ```
# 関数: tiktoken.get_encoding
# 引数: "gpt2"
# ```
#
# - tiktoken.get_encoding("gpt2") は、GPT-2 モデルに対応した トークナイザーを取得します。
# - 得られたトークナイザーは、テキストをトークンIDに変換したり、逆にデコードするために使われます。

# %%
encoder = tiktoken.get_encoding("gpt2") # TODO: 関数(引数)

# %% [markdown]
# ```python
# インスタンス: encoder
# メソッド: encode
# 引数: "tiktoken is great!"
# ```
#
# * `encode` は、文字列を **トークンIDのリスト** に変換します。
# * 結果の `encoded` は整数のリストになります。
# * ここでの `encoder` は `get_encoding()` で取得されたエンコーディングオブジェクトを指します。

# %%
encoded = encoder.encode("tiktoken is great!") # TODO: インスタンス.メソッド（引数）
print(encoded)
# Out:
# [83, 1134, 30001, 318, 1049, 0]

# %% [markdown]
# ```python
# インスタンス: encoder
# メソッド: decode
# 引数: THINK_BY_YOURLSELF
# ```
#
# * `decode` は、トークンIDのリストを文字列に復元するメソッドです。
# * `encoder`という名前なので`encode`しかできないと勘違いされがちですが、`decode`もできます。もともと`encoder`というインスタンス名自体が任意で自分で決めたものでもりますし。ただ、`encoder`や`enc`というインスタンス名をつけるのが一般的です。

# %%
decoded  = encoder.decode(encoded) # TODO: インスタンス.メソッド（引数）
print(decoded)
# Out:
# tiktoken is great!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Heppy:25082  birthday:10955, !:0, 🎁:8582, 236, 223
prompt = encoder.encode("Happy birthday!🎁")
print(prompt)
# Out:
# [25082, 10955, 0, 8582, 236, 223]

# %% [markdown]
# ## ◆ なぜ英語以外の言語をエンコードすると文字列が長くなるのか？
#
# GPT 系モデルが使う **tiktoken の辞書（サブワード辞書）は英語を中心に最適化**されています。
# そのため、
#
# * **英語でよく出てくる単語・部分語（サブワード）**は、辞書に登録されており短いトークンで表現できる
# * **英語以外（日本語・中国語など）でよく出る文字や単語は辞書に少ない**
#
# という差が生まれます。
#
# 辞書に無い文字は、そのまま「1 文字」として扱えず、
# **もっと細かい単位（バイト）に分解してからトークン化**されます。
#
# ---
#
# ## ◆ 「バイト」とは？（UTF-8 の観点で）
#
# **バイト（byte）**
#
# * コンピュータで扱う一番基本的な情報単位（8 ビット）
# * 1 バイト = 0〜255 の数を表現できる
# * アルファベットや数字の多くは **1 バイトで表現できる**
#
# **UTF-8**（世界中の文字を扱うための文字コード）では、
# 文字ごとに次のようにバイト数が異なります：
#
# | 文字                      | UTF-8で必要なバイト数 |
# | ----------------------- | ------------- |
# | 英語（A, B, C, a, b, c…）   | **1 バイト**     |
# | アクセント付き欧州文字（é, ö…）      | **1 バイト**     |
# | 日本語・中国語など（漢字・ひらがな・カタカナ） | **2 ~ 3 バイト**     |
# | 絵文字（😀など）               | **2 ~ 3 バイト**     |
#
# つまり、英語以外の文字は **1 文字でも複数バイト**になることが多いのです。
#
# ---
#
# ## ◆ 辞書にない文字は「バイト単位で分割」される
#
# tiktoken の仕組みでは：
#
# * 辞書にあるサブワード → **1 トークンで表現できる**
# * 辞書にない文字 → 文字を UTF-8 の **バイト列に分解して、それぞれをトークン化**する
#
# 例：
#
# * 英語「hello」 → 辞書にあるので **1 トークン**
# * 日本語「日」 → 辞書に無ければ
#
#   * UTF-8 バイト列（2バイト） = **2 トークン**
#
# というように、
# **英語以外では1トークンあたりの情報量が小さくなり、トークン数が増える＝文字列が長く見える**
# という現象が起きます。
#
#
# ---
#
# ## ◆ まとめ（とても簡潔に）
#
# * tiktoken の辞書は英語中心
# * 辞書にない文字は UTF-8 の **バイト（最小単位）** に分解される
# * 非英語はバイトに分解されることが多い
# * そのため英語以外は **トークン数が増え、見かけ上長くなる**

# %%
zh_prompt = encoder.encode("祝你生日快乐!🎁")
print(zh_prompt)
# Out:
# [163, 98, 251, 19526, 254, 37955, 33768, 98, 33232, 104, 20046, 238, 0, 8582, 236, 223]

# %%
ja_prompt = encoder.encode("お誕生日おめでとう!🎁")
print(ja_prompt)
# Out:
# [2515, 232, 45739, 243, 37955, 33768, 98, 2515, 232, 1792, 223, 30640, 30201, 29557, 0, 8582, 236, 223]

# %%
zh_decoded = encoder.decode(zh_prompt)
print(zh_decoded)
# Out:
# 祝你生日快乐!🎁

# %%
ja_decoded = encoder.decode(ja_prompt)
print(ja_decoded)
# Out:
# お誕生日おめでとう!🎁

# %%
import tiktoken

tokens = [2515, 232, 45739, 243, 37955, 33768, 98, 2515, 232, 1792, 223, 30640, 30201, 29557, 0, 8582, 236, 223]

for i, t in enumerate(tokens):
    s = encoder.decode_single_token_bytes(t).decode("utf-8", errors="replace")
    print(f"{i:02d}: {t:5d} → {repr(s)}")
# Out:
# 00:  2515 → '�'
# 01:   232 → '�'
# 02: 45739 → '�'
# 03:   243 → '�'
# 04: 37955 → '生'
# 05: 33768 → '�'
# 06:    98 → '�'
# 07:  2515 → '�'
# 08:   232 → '�'
# 09:  1792 → '�'
# 10:   223 → '�'
# 11: 30640 → 'で'
# 12: 30201 → 'と'
# 13: 29557 → 'う'
# 14:     0 → '!'
# 15:  8582 → '�'
# 16:   236 → '�'
# 17:   223 → '�'

# %% [markdown]
# **Section 1: tiktokenを使う**<label><input type="checkbox"> Mark as Done</label>

# %% [markdown]
# ### **Section 2: Byte Pair Encodingの事前知識（読むだけ）**

# %% [markdown]
# どうすればモデルの計算を高速化できるか？
#
# 最も簡単な発想は、**1文字ずつではなく、もっと大きな単位でトークン化する**ことです。
#
# たとえば
# `word` を
#
# ```
# [w], [o], [r], [d]
# ```
#
# の 4 トークンに分ける代わりに、
# 1つのトークン `[word]` として扱えば、シーケンス長は 1/4 になります。
#
# これで計算コストが大幅に下がります。
#
# ---
#
# ## 🔍 しかし、「すべての単語を1トークンにする」は現実的ではありません
#
# ここで問題になるのが **OOV（Out-of-Vocabulary）** です。
#
# * Mirzayeva (人の名前)
# * Tokyo
# * state-of-the-art
# * 新語・専門用語
# * 製品名・固有名詞
#
# など、自然言語の語彙には限りがありません。
#
# つまり言語タスクは **open-vocabulary（語彙が無限）** の問題。
#
# すべての単語を事前に登録しておくのは不可能です。
#
# ---
#
# さらに、世界には大量に複合語を作ってしまう言語もあります。
#
# 例えばドイツ語 🇩🇪 が代表例です。
#
# **Abwasserbehandlungsanlage**
#
# ...????? 😎🇩🇪🍺
#
# 正解:（sewage water treatment plant：下水処理施設）
#
#
#
#
#
# ドイツ語は意味のある語をどんどん連結して 1 単語にしてしまいます。
#
# 特に機械翻訳の世界では英語🇺🇸 ↔ ドイツ語🇩🇪 が代表的なタスクだったので、
#
# **ドイツ語の大量の複合語は大きな問題でした。**
#
# ---
#
# ## 🔍 では、文字レベルに戻せば OOV は起きない？
#
# 確かに、文字単位にすれば
# **どんな単語でも絶対に表現できます。**
#
# しかしその代わり：
#
# * トークン数が非常に長くなる
# * 計算コストが巨大
# * 文構造や形態素パターンを学習しにくい
#
# といった問題があります。
#
# ---
#
# ## 🔍 言語学的に意味のある分割（形態素解析）
#
# たとえば「Abwasserbehandlungsanlage」を意味のある形態素に分解すると：
#
# * **Abwasser**（汚水 = Ab〔除去〕 + Wasser〔水〕）
# * **Behandlungs-**（処理の = behandeln〔処理する〕＋ -ung）
# * **Anlage**（施設）
#
# 非常に自然で正しい分割ですが、
#
# * 言語知識が必要
# * 言語ごとに個別の形態素解析器が必要
#
# という理由で実務的には難しいのが現実です。
#
# ---
#
# # 🎯 **そこで登場したのが BPE（Byte Pair Encoding）**
#
# BPE のアイデアはとてもシンプルです：
#
# ### **1. まず文字（または byte）を基本単位として開始する（open vocabulary を保証）**
#
# ※2015 の原論文は文字レベル。
# ※GPT 系は UTF-8 バイトレベル。
#
# ### **2. 訓練データ中で頻出する文字列の組み合わせを、頻度の高い順に次々とマージする**
#
# これにより：
#
# * 新語・造語は文字から組み立て可能（open vocabulary）
# * よく出現する単語・部分語は圧縮されて短くなる（高い圧縮率）
# * 自然に形態素っぽいパターンも学習される（言語学的に厳密ではないが実用的）
#
# **文字レベルの柔軟性と単語レベルの効率の“ちょうど良いバランス”** を実現します。
#
# ---
#
# ##  🌍 **ドイツ語は BPE の恩恵を最もわかりやすく示した言語だが、**
#
# BPE が広く採用された理由は“普遍的に強い”から
#
# 確かに、ドイツ語のような複合語が多い言語は
# **BPE のメリットが劇的に見える代表例**でした。
#
# しかし BPE が現代 NLP の標準になった理由は
# **ドイツ語だけのためではありません。**
#
# BPE は他にも多くの言語と相性が良かったのです。
#
# ### ✔ 日本語・中国語（分かち書きなし）
#
# → 単語の境界が曖昧でも subword が自然に機能する
#
# ### ✔ トルコ語・フィンランド語（語形変化が爆発）
#
# → 膠着語では形態素が無限に増える
# → word-level が完全に破綻
#
# ### ✔ ロシア語・ポーランド語（屈折が激しい）
#
# → 語形変化が多すぎて辞書登録が不可能
#
# ### ✔ 英語（新語・スラング・固有名詞が無限）
#
# → 語彙が常に膨張するインターネット時代に対応
#
# ### ✔ コード（Python, HTML, URL）
#
# → 自然言語ではない記号列にも強い
#
# このように **BPE は「特定言語用の手法」ではなく、
# あらゆる言語と記号体系を一貫して扱える普遍的なアルゴリズム** だったことが大きいのです。
#
# ---
#
# # 🧠 **BPE が NLP 史上の標準になった理由（総まとめ）**
#
# * OOV がゼロ
# * 圧縮率が高い → Transformer の計算効率と相性抜群
# * 言語を問わず適用できる（普遍性）
# * 形態素的パターンを自然に学習
# * 辞書や解析器などの言語依存処理が不要
# * 多言語モデル（BERT, GPT）でそのまま使える
# * コードや絵文字などの非言語にも対応
#
# ドイツ語の複合語は「BPE の強みを示す象徴的な例」でしたが、
#
# BPE が勝ち残った理由は **“どの言語にも効く”** 普遍性が圧倒的だったためです。
#
# その普遍性が最初から意図されていたかどうかは分かりませんが、結果的に標準のtokenizer手法となりました。
#
# 反対に、それまで盛んだった言語ごとの形態素解析は下火になっていきました。
#
# ---
#
# 言語ごとの形態素解析が盛んだった2015年にあなたが生きていたとします。
#
# もしあなたが2015年にこの論文を見ていたら、果たしてどう反応すれば良かったのでしょう? https://arxiv.org/pdf/1508.07909
#
# なお、最初の論文では言語的な普遍性が強調されているわけではありません。
#
# むしろ低頻度単語に注目したニッチな研究にすら思えます。
#
# ただ、ドイツ語の複合語の対応だけではなく、ロシア語の名前の翻訳への対応力など、このシンプルな手法の普遍性はしっかり書かれています。
#
# また、結論の最後にも
#
# ```plain
# While the relative effectiveness will depend on
# language-specific factors such as vocabulary size,
# we believe that subword segmentations are suit-
# able for most language pairs
# ```
#
# という普遍性への期待が書かれています。
# <br><br>
#
# 私たちは想像を広げなければなりません。
#
# ある時、ある研究から出てきた、シンプルな手法が、圧倒的な普遍性を誇り、他の研究も含めて分野全体を席巻してしまうことを。
#
# つまり普遍性とは研究の質を決める非常に重要なキーなのです。
#
# 領域に特化したエンジニア的な職人芸にキャリアを預けることはリスクがあります。
#
# むしろ、職人芸を駆逐して普遍化していく部分に思考を寄せていくのです。
#
# ---
#
# 補足
#
# このBPEは2年後にあの伝説の論文`Attention is all you need`(2017)でも採用されることになります。元々の`Attention is all you need`も英独翻訳タスクなので、普遍性に着目したというよりかは、タスクが共通していたからだと思われるので自然な流れですね。
#
#
# 余談
#
# AIがAIについて完璧に教えてくれて教材も勝手に作ってしまったら、もう僕のやってる教材作りとかもいらなくなっちゃうね笑
#
# 普遍化の波のなかで職人芸は消失し、職人たちは失業していく、、、
#
# ただ逆にいうと、自分自身を失業させようとすれば普遍化の波を作る側になれるかも
#
# 自分のスキルセットをあえて時代遅れにする発明をした人たちが常に前を行く
#
# 🔥 outdate yourself!

# %% [markdown]
# **Section 2: Byte Pair Encodingの事前知識（読むだけ）**<label><input type="checkbox"> Mark as Done</label>

# %% [markdown]
# ### **Section 3: tiktokenで学習させる**

# %%
data_file = "https://huggingface.co/datasets/HuggingFaceFW/fineweb-edu/resolve/main/sample/10BT/000_00000.parquet"

# %%
from datasets import load_dataset
ds = load_dataset("parquet", data_files=data_file, split="train", cache_dir="/content/fineweb")
# Out:
# sample/10BT/000_00000.parquet:   0%|          | 0.00/2.15G [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]

# %% [markdown]
# `ds`は HuggingFace Datasets ライブラリ独自の `Dataset` クラスのインスタンスになっています。

# %%
ds
# Out:
# Dataset({
#     features: ['text', 'id', 'dump', 'url', 'file_path', 'language', 'language_score', 'token_count', 'score', 'int_score'],
#     num_rows: 726000
# })

# %% [markdown]
# 最初の要素を見てみましょう。

# %%
ds[0]
# Out:
# {'text': 'The Independent Jane\nFor all the love, romance and scandal in Jane Austen’s books, what they are really about is freedom and independence. Independence of thought and the freedom to choose.\nElizabeth’s refusal of Mr. Collins offer of marriage showed an independence seldom seen in heroines of the day. Her refusal of Mr. Darcy while triggered by anger showed a level of independence that left him shocked and stunned.\nThe freedom she exhibited in finally accepting him in direct defiance of Lady Catherine and knowing her father would disapprove was unusual even for Austen. In her last book Anne Elliot is persuaded to refuse Captain Wentworth at Lady Russel’s insistence.\nAlthough Jane played by the rules of the day, all of her writing is infused with how she wanted life to be. She ‘screams’ her outrage at the limitations for women in Emma.\nWhen accosted by Mrs. Elton, Jane Fairfax says,\n“Excuse me, ma’am, but this is by no means my intention; I make no inquiry myself, and should be sorry to have any made by my friends. When I am quite determined as to the time, I am not at all afraid of being long unemployed. There are places in town, offices, where inquiry would soon produce something — offices for the sale, not quite of human flesh, but of human intellect.”\n“Oh! my dear, human flesh! You quite shock me; if you mean a fling at the slave-trade, I assure you Mr. Suckling was always rather a friend to the abolition.”\n“I did not mean, I was not thinking of the slave-trade,” replied Jane; “governess-trade, I assure you, was all that I had in view; widely different certainly, as to the guilt of those who carry it on; but as to the greater misery of the victims, I do not know where it lies.”\nThat same sentiment is emphasized in Emma’s shock when Mrs. Weston tells her of Frank Churchill’s secret engagement to Jane.\n“Good God!” cried Emma, “Jane actually on the point of going as governess! What could he mean by such horrible indelicacy? To suffer her to engage herself — to suffer her even to think of such a measure!”\nI find it interesting that at the moment of Austen’s birth or there about, John Adams left his farm in Massachusetts for the Continental Congress in Philadelphia. Doesn’t sound particularly interesting, I know but consider this.\nJohn Adams left his home in mid-December 1775 to attend an unprecedented meeting of colonial representatives to consider severing ties with their mother country and her monarch; a decision that culminated in a document unlike any ever written. In the mother country, one day in that same cold December a baby girl was born at Steventon Rectory. Her cry was heard by only the people in the house but the years to come would see her pen create works unlike any the world had ever seen.\nComparing Austen’s words with Thomas Jefferson’s may seem a trivialization but I believe that Austen’s impact on the world is no less important than Jefferson’s. The effect of Jane’s writing maybe more subtle than that of the Virginian but it is no less influential.\nJefferson’s words instigated and promoted a revolution, a war of independence. Jane’s words had no such excessive consequence. Still in her own quiet, genteel yet powerful way she declared and promoted the same principles of freedom and self-regulated independence as our American forefathers. In all her novels Jane advocates independence of person and thought, the rights of all and acceptance of responsibility for those rights.\nJane may not have incited military action as Jefferson did but even as an avowed royalist, I doubt not that Jane Austen firmly believed in his declaration of the right to life, liberty and the pursuit of happiness.',
#  'id': '<urn:uuid:0d8a309d-25c5-405d-a08a-c11239f0d717>',
#  'dump': 'CC-MAIN-2013-20',
#  'url': 'http://austenauthors.net/the-independent-jane',
#  'file_path': 's3://commoncrawl/crawl-data/CC-MAIN-2013-20/segments/1368696381249/warc/CC-MAIN-20130516092621-00000-ip-10-60-113-184.ec2.internal.warc.gz',
#  'language': 'en',
#  'language_score': 0.9743200540542603,
#  'token_count': 845,
#  'score': 2.75,
#  'int_score': 3}

# %% [markdown]
# `ds` には、各データサンプルごとに `text` カラムがあり、そこに文章が格納されています。
#
# そのため、文章の区切りとして、前回は「🄴」という特殊文字を使いましたが、
#
# tiktokenには`<|endoftext|>`という特殊トークンがあるので、今回はこれを使います。
#
# `<|endoftext|>` を区切り文字として利用し、複数の文章を無理なく連結します。

# %%
# 文書境界
boundary = "<|endoftext|>"
encoded_boundary = encoder.encode(boundary, allowed_special="all") # TODO: インスタンス.メソッド（引数）
print(encoded_boundary)
# Out:
# [50256]

# %%
with open("fineweb.txt", "w", encoding="utf-8") as f:
    for sample in ds:
        f.write(boundary + sample["text"])

# %%
# `fineweb.txt`のディスクサイズを計測するコマンド。通常の関数とは異なります。
# !ls -lh fineweb.txt
# Out:
# -rw-r--r-- 1 root root 3.3G Nov 22 06:18 fineweb.txt

# %% [markdown]
# 実は、この `fineweb.txt` は **ディスクサイズで約 3.3GB** もあります。
#
# データのロードは文字のencodingなどの重たい処理を含んでいます。
#
# このまま全データをロードしようとすると、**システム RAM が不足してクラッシュ**してしまいます。
#
# 前回は 約 70 万サンプルのうち、5万サンプルだけを使用した`nanofineweb.txt`を作成しました。
#
# 今回はtiktokenを用いてサブワードでトークン化しているため、圧縮率が高いです。
#
# データがすぐになくなってしまいます。
#
# そこで、10万サンプルを使用します。
#
# 本当はもっとサンプルが必要なのですが、システムRAMの制限からこの量としています。

# %%
with open("nanofineweb.txt", "w", encoding="utf-8") as f:
    for i, sample in enumerate(ds):
        if i >= 500_000:
            break
        f.write(boundary + sample["text"])

# %%
# `nanofineweb.txt`のディスクサイズを計測するコマンド。通常の関数とは異なります。
# !ls -lh nanofineweb.txt
# Out:
# -rw-r--r-- 1 root root 2.3G Nov 22 06:19 nanofineweb.txt

# %% [markdown]
# `nanofineweb.txt`について、最初の10,000文字を表示してみましょう。

# %%
with open("nanofineweb.txt", "r", encoding="utf-8") as f:
  text = f.read(10000)
  print(text)
# Out:
# <|endoftext|>The Independent Jane
# For all the love, romance and scandal in Jane Austen’s books, what they are really about is freedom and independence. Independence of thought and the freedom to choose.
# Elizabeth’s refusal of Mr. Collins offer of marriage showed an independence seldom seen in heroines of the day. Her refusal of Mr. Darcy while triggered by anger showed a level of independence that left him shocked and stunned.
# The freedom she exhibited in finally accepting him in direct defiance of Lady Catherine and knowing her father would disapprove was unusual even for Austen. In her last book Anne Elliot is persuaded to refuse Captain Wentworth at Lady Russel’s insistence.
# Although Jane played by the rules of the day, all of her writing is infused with how she wanted life to be. She ‘screams’ her outrage at the limitations for women in Emma.
# When accosted by Mrs. Elton, Jane Fairfax says,
# “Excuse me, ma’am, but this is by no means my intention; I make no inquiry myself, and should be sorry to have any made by my friends. When I am quite determined as to the time, I am not at all afraid of being long unemployed. There are places in town, offices, where inquiry would soon produce something — offices for the sale, not quite of human flesh, but of human intellect.”
# “Oh! my dear, human flesh! You quite shock me; if you mean a fling at the slave-trade, I assure you Mr. Suckling was always rather a friend to the abolition.”
# “I did not mean, I was not thinking of the slave-trade,” replied Jane; “governess-trade, I assure you, was all that I had in view; widely different certainly, as to the guilt of those who carry it on; but as to the greater misery of the victims, I do not know where it lies.”
# That same sentiment is emphasized in Emma’s shock when Mrs. Weston tells her of Frank Churchill’s secret engagement to Jane.
# “Good God!” cried Emma, “Jane actually on the point of going as governess! What could he mean by such horrible indelicacy? To suffer her to engage herself — to suffer her even to think of such a measure!”
# I find it interesting that at the moment of Austen’s birth or there about, John Adams left his farm in Massachusetts for the Continental Congress in Philadelphia. Doesn’t sound particularly interesting, I know but consider this.
# John Adams left his home in mid-December 1775 to attend an unprecedented meeting of colonial representatives to consider severing ties with their mother country and her monarch; a decision that culminated in a document unlike any ever written. In the mother country, one day in that same cold December a baby girl was born at Steventon Rectory. Her cry was heard by only the people in the house but the years to come would see her pen create works unlike any the world had ever seen.
# Comparing Austen’s words with Thomas Jefferson’s may seem a trivialization but I believe that Austen’s impact on the world is no less important than Jefferson’s. The effect of Jane’s writing maybe more subtle than that of the Virginian but it is no less influential.
# Jefferson’s words instigated and promoted a revolution, a war of independence. Jane’s words had no such excessive consequence. Still in her own quiet, genteel yet powerful way she declared and promoted the same principles of freedom and self-regulated independence as our American forefathers. In all her novels Jane advocates independence of person and thought, the rights of all and acceptance of responsibility for those rights.
# Jane may not have incited military action as Jefferson did but even as an avowed royalist, I doubt not that Jane Austen firmly believed in his declaration of the right to life, liberty and the pursuit of happiness.<|endoftext|>Taking Play Seriously
# By ROBIN MARANTZ HENIG
# Published: February 17, 2008
# On a drizzly Tuesday night in late January, 200 people came out to hear a psychiatrist talk rhapsodically about play -- not just the intense, joyous play of children, but play for all people, at all ages, at all times. (All species too; the lecture featured touching photos of a polar bear and a husky engaging playfully at a snowy outpost in northern Canada.) Stuart Brown, president of the National Institute for Play, was speaking at the New York Public Library's main branch on 42nd Street. He created the institute in 1996, after more than 20 years of psychiatric practice and research persuaded him of the dangerous long-term consequences of play deprivation. In a sold-out talk at the library, he and Krista Tippett, host of the public-radio program ''Speaking of Faith,'' discussed the biological and spiritual underpinnings of play. Brown called play part of the ''developmental sequencing of becoming a human primate. If you look at what produces learning and memory and well-being, play is as fundamental as any other aspect of life, including sleep and dreams.''
# The message seemed to resonate with audience members, who asked anxious questions about what seemed to be the loss of play in their children's lives. Their concern came, no doubt, from the recent deluge of eulogies to play . Educators fret that school officials are hacking away at recess to make room for an increasingly crammed curriculum. Psychologists complain that overscheduled kids have no time left for the real business of childhood: idle, creative, unstructured free play. Public health officials link insufficient playtime to a rise in childhood obesity. Parents bemoan the fact that kids don't play the way they themselves did -- or think they did. And everyone seems to worry that without the chance to play stickball or hopscotch out on the street, to play with dolls on the kitchen floor or climb trees in the woods, today's children are missing out on something essential.
# The success of ''The Dangerous Book for Boys'' -- which has been on the best-seller list for the last nine months -- and its step-by-step instructions for activities like folding paper airplanes is testament to the generalized longing for play's good old days. So were the questions after Stuart Brown's library talk; one woman asked how her children will learn trust, empathy and social skills when their most frequent playing is done online. Brown told her that while video games do have some play value, a true sense of ''interpersonal nuance'' can be achieved only by a child who is engaging all five senses by playing in the three-dimensional world.
# This is part of a larger conversation Americans are having about play. Parents bobble between a nostalgia-infused yearning for their children to play and fear that time spent playing is time lost to more practical pursuits. Alarming headlines about U.S. students falling behind other countries in science and math, combined with the ever-more-intense competition to get kids into college, make parents rush to sign up their children for piano lessons and test-prep courses instead of just leaving them to improvise on their own; playtime versus r?m?uilding.
# Discussions about play force us to reckon with our underlying ideas about childhood, sex differences, creativity and success. Do boys play differently than girls? Are children being damaged by staring at computer screens and video games? Are they missing something when fantasy play is populated with characters from Hollywood's imagination and not their own? Most of these issues are too vast to be addressed by a single field of study (let alone a magazine article). But the growing science of play does have much to add to the conversation. Armed with research grounded in evolutionary biology and experimental neuroscience, some scientists have shown themselves eager -- at times perhaps a little too eager -- to promote a scientific argument for play. They have spent the past few decades learning how and why play evolved in animals, generating insights that can inform our understanding of its evolution in humans too. They are studying, from an evolutionary perspective, to what extent play is a luxury that can be dispensed with when there are too many other competing claims on the growing brain, and to what extent it is central to how that brain grows in the first place.
# Scientists who study play, in animals and humans alike, are developing a consensus view that play is something more than a way for restless kids to work off steam; more than a way for chubby kids to burn off calories; more than a frivolous luxury. Play, in their view, is a central part of neurological growth and development -- one important way that children build complex, skilled, responsive, socially adept and cognitively flexible brains.
# Their work still leaves some questions unanswered, including questions about play's darker, more ambiguous side: is there really an evolutionary or developmental need for dangerous games, say, or for the meanness and hurt feelings that seem to attend so much child's play? Answering these and other questions could help us understand what might be lost if children play less.<|endoftext|>How do you get HIV?
# HIV can be passed on when infected bodily fluid, such as blood or semen, is passed into an uninfected person. Semen is the liquid which is released from a man's penis during sex which carries sperm. It can be infected with HIV or AIDS when someone is HIV positive or is carrying the AIDS virus. This can happen during unprotected sex. For example when two people have sex without using a condom when one partner is already infected, or between drug users who inject and share needles.
# It can't be transmitted by things like coughing, sneezing, kissing, sharing a toilet seat, swimming pools, sweat and tears.<|endoftext|>CTComms sends on average 2 million emails monthly on behalf of over 125 different charities and not for profits.
# Take the complexity of technology and stir in the complexity of the legal system and what do you get? Software licenses! If you've ever attempted to read one you know how true this is, but you have to know a little about software licensing even if you can't parse all of the fine print.

# %% [markdown]
# `Dataloader`クラスをtiktokenライブラリ対応に変えます。

# %% [markdown]
# 🔘 **Options**: 余計な選択肢があるかもしれません。同じ選択肢を2回以上使うかもしれません。
#
# `tiktoken`　`openai`　`get_encoding`　`encoder`　`decoder`　`encode`　`decode`

# %%
"""
import torch
########## NEW ##########
import ________
########## NEW ##########

class DataLoader:
    def __init__(self, text, config):
        self.config = config  # Configuration Object

        ########## NEW ##########
        self.encoder = ________.___________("gpt2")
        self.vocab_size = self.encoder.n_vocab
        ########## NEW ##########

        # Encode and convert to tensor.
        self.data = torch.tensor(self.encode(text), dtype=torch.long)

        # Split into training/validation data.
        self.train_data, self.val_data = self.split_data()

    def encode(self, text):
        ########## NEW ##########
        # tiktokenでエンコード
        return self._______._____(text, allowed_special="all")
        ########## NEW ##########

    def decode(self, indices):
        ########## NEW ##########
        # tiktokenでデコード
        return self._______.______(indices)
        ########## NEW ##########

    def split_data(self):
        split_index = int(0.9 * len(self.data))  # 90% train, 10% val
        return self.data[:split_index], self.data[split_index:]

    def get_batch(self, split):
        data = self.train_data if split == 'train' else self.val_data
        start_indices = torch.randint(
            len(data) - self.config.input_sequence_length,
            (self.config.batch_size,)
        )

        input_sequences = torch.stack([
            data[start:start + self.config.input_sequence_length]
            for start in start_indices
        ])
        target_sequences = torch.stack([
            data[start + 1:start + self.config.input_sequence_length + 1]
            for start in start_indices
        ])

        return (
            input_sequences.to(self.config.device_type),
            target_sequences.to(self.config.device_type)
        )
"""
# Out:
# '\nimport torch\n########## NEW ##########\nimport ________\n########## NEW ##########\n\nclass DataLoader:\n    def __init__(self, text, config):\n        self.config = config  # Configuration Object\n\n        ########## NEW ##########\n        self.encoder = ________.___________("gpt2")\n        self.vocab_size = self.encoder.n_vocab\n        ########## NEW ##########\n\n        # Encode and convert to tensor.\n        self.data = torch.tensor(self.encode(text), dtype=torch.long)\n\n        # Split into training/validation data.\n        self.train_data, self.val_data = self.split_data()\n\n    def encode(self, text):\n        ########## NEW ##########\n        # tiktokenでエンコード\n        return self._______._____(text, allowed_special="all")\n        ########## NEW ##########\n\n    def decode(self, indices):\n        ########## NEW ##########\n        # tiktokenでデコード\n        return self._______.______(indices)\n        ########## NEW ##########\n\n    def split_data(self):\n        split_index = int(0.9 * len(self.data))  # 90% train, 10% val\n        return self.data[:split_index], self.data[split_index:]\n\n    def get_batch(self, split):\n        data = self.train_data if split == \'train\' else self.val_data\n        start_indices = torch.randint(\n            len(data) - self.config.input_sequence_length,\n            (self.config.batch_size,)\n        )\n\n        input_sequences = torch.stack([\n            data[start:start + self.config.input_sequence_length]\n            for start in start_indices\n        ])\n        target_sequences = torch.stack([\n            data[start + 1:start + self.config.input_sequence_length + 1]\n            for start in start_indices\n        ])\n\n        return (\n            input_sequences.to(self.config.device_type),\n            target_sequences.to(self.config.device_type)\n        )\n'

# %%
import torch
########## NEW ##########
import tiktoken
########## NEW ##########

class DataLoader:
    def __init__(self, text, config):
        self.config = config  # Configuration Object

        ########## NEW ##########
        self.encoder = tiktoken.get_encoding("gpt2")
        self.vocab_size = self.encoder.n_vocab
        ########## NEW ##########

        # Encode and convert to tensor.
        self.data = torch.tensor(self.encode(text), dtype=torch.long)

        # Split into training/validation data.
        self.train_data, self.val_data = self.split_data()

    def encode(self, text):
        ########## NEW ##########
        # tiktokenでエンコード
        return self.encoder.encode(text, allowed_special="all")
        ########## NEW ##########

    def decode(self, indices):
        ########## NEW ##########
        # tiktokenでデコード
        return self.encoder.decode(indices)
        ########## NEW ##########

    def split_data(self):
        split_index = int(0.9 * len(self.data))  # 90% train, 10% val
        return self.data[:split_index], self.data[split_index:]

    def get_batch(self, split):
        data = self.train_data if split == 'train' else self.val_data
        start_indices = torch.randint(
            len(data) - self.config.input_sequence_length,
            (self.config.batch_size,)
        )

        input_sequences = torch.stack([
            data[start:start + self.config.input_sequence_length]
            for start in start_indices
        ])
        target_sequences = torch.stack([
            data[start + 1:start + self.config.input_sequence_length + 1]
            for start in start_indices
        ])

        return (
            input_sequences.to(self.config.device_type),
            target_sequences.to(self.config.device_type)
        )

# %% [markdown]
# <details>
# <summary>クリックして答えを表示/非表示</summary>
#
# ```python
# import torch
# ########## NEW ##########
# import tiktoken
# ########## NEW ##########
#
# class DataLoader:
#     def __init__(self, text, config):
#         self.config = config  # Configuration Object
#
#         ########## NEW ##########
#         self.encoder = tiktoken.get_encoding("gpt2")
#         self.vocab_size = self.encoder.n_vocab
#         ########## NEW ##########
#
#         # Encode and convert to tensor.
#         self.data = torch.tensor(self.encode(text), dtype=torch.long)
#
#         # Split into training/validation data.
#         self.train_data, self.val_data = self.split_data()
#
#     def encode(self, text):
#         ########## NEW ##########
#         # tiktokenでエンコード
#         return self.encoder.encode(text, allowed_special="all")
#         ########## NEW ##########
#
#     def decode(self, indices):
#         ########## NEW ##########
#         # tiktokenでデコード
#         return self.encoder.decode(indices)
#         ########## NEW ##########
#
#     def split_data(self):
#         split_index = int(0.9 * len(self.data))  # 90% train, 10% val
#         return self.data[:split_index], self.data[split_index:]
#
#     def get_batch(self, split):
#         data = self.train_data if split == 'train' else self.val_data
#         start_indices = torch.randint(
#             len(data) - self.config.input_sequence_length,
#             (self.config.batch_size,)
#         )
#
#         input_sequences = torch.stack([
#             data[start:start + self.config.input_sequence_length]
#             for start in start_indices
#         ])
#         target_sequences = torch.stack([
#             data[start + 1:start + self.config.input_sequence_length + 1]
#             for start in start_indices
#         ])
#
#         return (
#             input_sequences.to(self.config.device_type),
#             target_sequences.to(self.config.device_type)
#         )
# ```

# %% [markdown]
# それ以外は前回のChapterと同じです。

# %%
class TokenEmbedding(nn.Module):
    def __init__(self, vocab_size, embedding_dim):
        super().__init__()
        # 語彙数x埋め込み次元の埋め込みテーブルを定義する
        self.token_embedding_table = nn.Embedding(vocab_size, embedding_dim)

    def embed(self, input_indices):
        # 入力インデックスに対応する埋め込みベクトルを取得する
        return self.token_embedding_table.forward(input_indices)

class PositionEmbedding(nn.Module):
    def __init__(self, input_sequence_length = 8, embedding_dim = 8):
        super().__init__()
        # 位置埋め込み層
        self.position_embedding_layer = nn.Embedding(input_sequence_length, embedding_dim)

    def forward(self, input_indices):
        # 入力テンソル input_indices の形状：[バッチサイズ、シーケンス長]。
        sequence_length = input_indices.shape[1]

        # シーケンス長に応じた位置インデックスを作成する（例：[0, 1, 2, ..., sequence_length-1]）
        position_indices = torch.arange(sequence_length, device=input_indices.device)

        # 位置インデックスの埋め込みベクトルを取得する
        position_embeddings = self.position_embedding_layer.forward(position_indices)

        return position_embeddings

class EmbeddingModule(nn.Module):
    def __init__(self, vocab_size, config):
        super().__init__()
        # 各トークンの埋め込み層
        self.token_embedding_layer = TokenEmbedding(vocab_size = vocab_size, embedding_dim = config.embedding_dim)  # 単語埋め込み層
        self.position_embedding_layer = PositionEmbedding(input_sequence_length = config.input_sequence_length, embedding_dim = config.embedding_dim)  # 位置情報を埋め込む

    def forward(self, input_indices):
        # トークン埋め込みを取得
        token_embeddings = self.token_embedding_layer.embed(input_indices)

        # 位置埋め込みを取得する
        position_embeddings = self.position_embedding_layer.forward(input_indices)

        # トークン埋め込みと位置埋め込みを追加する
        embeddings = position_embeddings + token_embeddings
        return embeddings


class AttentionHead(nn.Module):
    def __init__(self, head_size, config):
        super().__init__()
        self.key_fc= nn.Linear(config.embedding_dim, head_size, bias=False)
        self.query_fc = nn.Linear(config.embedding_dim, head_size, bias=False)
        self.value_fc = nn.Linear(config.embedding_dim, head_size, bias=False)

        # ドロップアウト
        self.dropout = nn.Dropout(config.dropout_rate)
        self.head_size = head_size

    def forward(self, input_tensor):
        B, T, C = input_tensor.shape  # バッチ、トークン長、埋め込みチャネル

        Key = self.key_fc.forward(input_tensor)     # (B, T, head_size)
        Query = self.query_fc.forward(input_tensor)   # (B, T, head_size)
        Value = self.value_fc.forward(input_tensor)   # (B, T, head_size)

        # Attentionスコアを計算中 (QK^T) / sqrt(embedding_dim)
        attention_weights_before_mask = Query @ Key.transpose(-2, -1) * self.head_size**(-0.5)

        # マスク適用済み
        mask = torch.triu(torch.ones(T, T), diagonal=1).to(input_tensor.device)
        masked_attention_weights = attention_weights_before_mask.masked_fill(mask == 1, float('-inf'))

        # ソフトマックス → ドロップアウト → 重み付き和
        attention_weights = F.softmax(masked_attention_weights, dim=-1)
        attention_weights = self.dropout(attention_weights)

        out = attention_weights @ Value  # (B, T, head_size)
        return out


class MultiHeadAttention(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.config = config
        self.num_attention_heads = config.num_attention_heads
        self.embedding_dim = config.embedding_dim
        self.head_size = int(self.embedding_dim / self.num_attention_heads)

        # ModuleListで複数のヘッドを管理する
        self.attention_heads = nn.ModuleList([
            AttentionHead(self.head_size, config)
            for _ in range(self.num_attention_heads)
        ])

        # 各ヘッドの出力を混合する線形層
        self.output_projection = nn.Linear(self.embedding_dim, self.embedding_dim)

        # 出力のドロップアウト
        self.dropout = nn.Dropout(config.dropout_rate)

    def forward(self, input_tensor):
        # 各ヘッドの出力を取得する
        # (B, T, head_size)のリスト
        head_outputs_list = [head.forward(input_tensor) for head in self.attention_heads]

        # 全てのヘッドの出力を連結 → (B, T, embedding_dim)
        concatenated = torch.cat(head_outputs_list, dim=-1)

        # 線形変換での出力混合
        projected = self.output_projection.forward(concatenated)

        # 最終出力にドロップアウトを適用する
        output = self.dropout.forward(projected)

        return output

class FeedForward(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(config.embedding_dim, config.hidden_dim),
            nn.ReLU(),
            nn.Linear(config.hidden_dim, config.embedding_dim),
            nn.Dropout(config.dropout_rate),
        )

    def forward(self, input_tensor):
        return self.net(input_tensor)

class TransformerBlock(nn.Module):
    def __init__(self, config):
        super().__init__()

        # 各LayerNormは独自のbetaとgammaを保持します。
        self.layer_norm1 = nn.LayerNorm(config.embedding_dim)
        self.layer_norm2 = nn.LayerNorm(config.embedding_dim)

        self.multihead_attention = MultiHeadAttention(config=config)
        self.feed_forward = FeedForward(config=config)

    def forward(self, input_tensor):
        # forwardメソッドは省略されています。
        normed_input = self.layer_norm1(input_tensor) # 入力にレイヤーノルムを適用する
        attention_output = self.multihead_attention(normed_input) # マルチヘッドアテンションを適用する
        residual_attention = attention_output + input_tensor # "before! layernorm1"を追加
        normed_attention = self.layer_norm2(residual_attention) # 残差出力に再度LayerNormを適用する
        feedforward_output = self.feed_forward(normed_attention) # フィードフォワードネットワークを適用する
        final_output = feedforward_output + residual_attention # "before" layernorm2 を追加する！

        return final_output

class VocabularyLogits(nn.Module):
    def __init__(self, vocab_size, config):
        super().__init__()
        # レイヤー正規化
        self.output_norm = nn.LayerNorm(config.embedding_dim)
        # 語彙数の射影
        self.vocab_projection = nn.Linear(config.embedding_dim, vocab_size)

    def forward(self, transformer_block_output):
        # Transformerブロックの出力にLayer normalizationを適用する。
        normalized_output = self.output_norm.forward(transformer_block_output)  # (B, T, C)

        # 線形層でスコアを語彙数次元に変換する。
        vocab_logits = self.vocab_projection.forward(normalized_output)  # (B, T, V)

        return vocab_logits

class nanoGPT(nn.Module):
    def __init__(self, vocab_size, config):
        super().__init__()
        self.config = config  # 生成時にも使うので保持してください。
        self.embedding = EmbeddingModule(vocab_size, config=config)
        self.blocks = nn.Sequential(*[TransformerBlock(config=config) for _ in range(config.layer_count)])
        self.vocab_projection = VocabularyLogits(vocab_size=vocab_size, config=config)
        self.criterion = nn.CrossEntropyLoss()

    # テキストを生成する
    def generate(self, input_indices, max_new_tokens):
        # 指定したトークン数max_new_tokensのみ生成する
        for _ in range(max_new_tokens):
            input_conditioned = input_indices[:, -self.config.input_sequence_length:] # 入力を切り取る

            # 順伝播は `(likelihood, loss)` を返す—`likelihood` のみを `logits` として保持する。
            logits, _ = self.forward(input_conditioned, target_indices=None)
            last_logits = logits[:, -1, :] # 最後のトークンのロジットを抽出する
            probs = F.softmax(last_logits, dim=-1) # Softmaxで尤度を確率に変換する

            # 次のトークンをサンプリングする
            next_token = torch.multinomial(probs, num_samples=1)

            # 新しいトークンを統合し、input_indicesを更新する。
            input_indices = torch.cat((input_indices, next_token), dim=1)

        # 最終的な`input_indices`を返す。長さは元の`input_indices`＋`max_new_tokens`
        return input_indices

    # 尤度と損失を計算する
    def forward(self, input_indices, target_indices):
        embeddings = self.embedding(input_indices)
        blocks_output = self.blocks(embeddings)
        logits = self.vocab_projection(blocks_output)

        # 推論時はターゲットがないため、lossはNoneです
        # —確率（ロジット）のみ返されます。
        if target_indices is None:
            return logits, None

        batch_size, token_len, vocab_size = logits.shape
        logits = logits.view(batch_size * token_len, vocab_size)
        targets = target_indices.view(batch_size * token_len)
        loss = self.criterion(logits, targets)

        return logits, loss

# %% [markdown]
# `Trainer`クラスを定義します。Chapter16と完全に同じです。

# %%
import time

class Trainer:
    def __init__(self, model, optimizer, data_loader, config):
        self.model = model
        self.optimizer = optimizer
        self.data_loader = data_loader
        self.config = config

        self.steps = []
        self.train_losses = []
        self.val_losses = []
        self.total_seen_tokens_list = []
        self.total_train_time_list = []

    def train_step(self):
        # トレーニング用バッチを取得。
        input_batch, target_batch = self.data_loader.get_batch('train')
        self.optimizer.zero_grad()

        # モデルの順伝播と損失計算
        logits, loss = self.model(input_batch, target_batch)
        loss.backward()  # 誤差逆伝播
        self.optimizer.step()  # パラメータ更新

        return loss.item() # 損失の値を返す

    def evaluate(self):
        self.model.eval()  # 評価モードに切り替え
        losses = {"train": [], "val": []} # 学習・検証データ両方の損失を計算
        with torch.no_grad():
            for split in ['train', 'val']:
                for _ in range(self.config.evaluation_loops):
                    input_batch, target_batch = self.data_loader.get_batch(split)
                    _, loss = self.model(input_batch, target_batch)
                    losses[split].append(loss.item())
        self.model.train()  # 再び学習モードへ戻す

        # 各データセット（train, val）での損失の平均を計算して返す
        return {split: sum(values) / len(values) for split, values in losses.items()}

    def train(self):
        # (configで指定された回数+1)だけtrain_stepを実行する。
        for step in range(self.config.total_training_steps+1):
            # 100回ごとに評価する。
            if step % self.config.evaluation_frequency == 0:
                if step == 0:
                  tokens_per_second = None
                  total_train_time = 0
                else:
                  current_eval_start_time = time.time()
                  evaluation_interval = current_eval_start_time - last_eval_end_time
                  total_train_time += evaluation_interval
                  tokens_per_evaluation_interval = self.config.batch_size * self.config.input_sequence_length * self.config.evaluation_frequency
                  tokens_per_second = tokens_per_evaluation_interval / evaluation_interval

                eval_loss = self.evaluate()
                total_seen_tokens = self.config.batch_size * self.config.input_sequence_length * step

                print(
                    f"step {step:05d} | "
                    f"train loss {eval_loss['train']:.4f} | "
                    f"val loss {eval_loss['val']:.4f} | "
                    f"tok/s {int(tokens_per_second) if tokens_per_second is not None else 'None'} | "
                    f"tokens {total_seen_tokens:,} | "
                    f"time {total_train_time:.2f}s"
                )

                self.steps.append(step)
                self.train_losses.append(eval_loss['train'])
                self.val_losses.append(eval_loss['val'])
                self.total_seen_tokens_list.append(total_seen_tokens)
                self.total_train_time_list.append(total_train_time)

                # この評価が終わった時間を記録する。次の評価開始時との時間差が`evaluation_interval`となる。
                last_eval_end_time = time.time()

            # 1回の学習ステップ（毎回行う主な処理）
            train_loss = self.train_step()

# %%
# モデル設定を保存する設定クラス
class ModelConfig:
    batch_size = 16
    input_sequence_length = 512  # データロードにかかる時間の割合を下げるため、長めのシークエンスを一度に取り出す。
    ########## NEW ##########
    total_training_steps = 100_000  # おおよそ1時間くらいかかる
    ########## NEW ##########
    device_type = 'cuda'  # 使用デバイスはGPUに固定する
    evaluation_frequency = 100  # モデル性能評価の頻度
    learning_rate = 0.001  # 学習率
    evaluation_loops = 10  # 評価中の繰り返し回数
    embedding_dim = 512  # 埋め込み層サイズ（特徴ベクトルの次元数）
    hidden_dim = 2048
    num_attention_heads = 8  # アテンションヘッドの数
    layer_count = 4  # モデルの層数
    dropout_rate = 0.1  # ドロップアウト確率
    random_seed_value = 1337  # 再現性のための乱数シード

# %%
# 設定を読み込みシードを設定する
config = ModelConfig()
torch.manual_seed(config.random_seed_value)  # 再現性確保のため乱数シードを設定

# %%
# データを読み込む。ファイルが大きいほどシステムRAMを消費します。
with open("/content/nanofineweb.txt", 'r', encoding = 'utf-8') as f:
    text_data = f.read()
data_loader = DataLoader(text_data, config)

# %% [markdown]
# tiktokenの語彙は巨大で、約50,000です。

# %%
vocab_size = data_loader.vocab_size
print(f"Vocab size: {vocab_size}")
# Out:
# Vocab size: 50257

# %%
# モデルとオプティマイザを初期化する
model = nanoGPT(vocab_size = data_loader.vocab_size, config = config).to(config.device_type)
optimizer = torch.optim.AdamW(model.parameters(), lr=config.learning_rate)

# %% [markdown]
# モデルのパラメータ数は前回の17Mから64Mと急激に増加します。
#
# 依然として計算コストにおける`nn.Embedding`の影響は軽微ですが、
#
# 出力層は大きな負担となります。

# %%
# モデルのパラメータ数を表示する
print(sum(p.numel() for p in model.parameters())/1e6, 'M parameters')
# Out:
# 64.379985 M parameters

# %% [markdown]
# ### 🚀 学習スタート！
#
# 今回は **15 GB RAM の T4 GPU** を使用し、
# `batch size = 16`、`total steps = 5,000` の設定で進めます。
#
# モデルサイズが大きくなった影響で、1stepあたりに時間がかかるようになったため、
#
# total steps は前回の10,000から5,000に引き下げられています。
#
# 本当は10,000step学習させたいのですが、とりあえず前回の5,000stepまでの比較はできるのでよしとしましょう。
#
# **学習完了までにおよそ1時間**ほどかかります😇
#
# 同じく、かなりヒマです…。
#
# 余裕がある方は論文を読んでみましょう。
#
#  https://arxiv.org/pdf/1508.07909

# %%
print("===トレーニングが正常に開始されました===")

# モデルを学習する
trainer = Trainer(model, optimizer, data_loader, config)
trainer.train()
# Out:
# ===トレーニングが正常に開始されました===
# step 00000 | train loss 10.9983 | val loss 10.9940 | tok/s None | tokens 0 | time 0.00s
# step 00100 | train loss 7.1213 | val loss 7.1288 | tok/s 47716 | tokens 819,200 | time 17.17s
# step 00200 | train loss 6.8264 | val loss 6.7966 | tok/s 48604 | tokens 1,638,400 | time 34.02s
# step 00300 | train loss 6.6188 | val loss 6.6280 | tok/s 48750 | tokens 2,457,600 | time 50.83s
# step 00400 | train loss 6.4371 | val loss 6.4577 | tok/s 48585 | tokens 3,276,800 | time 67.69s
# step 00500 | train loss 6.3724 | val loss 6.4022 | tok/s 48604 | tokens 4,096,000 | time 84.54s
# step 00600 | train loss 6.2676 | val loss 6.2686 | tok/s 48649 | tokens 4,915,200 | time 101.38s
# step 00700 | train loss 6.2186 | val loss 6.2197 | tok/s 48621 | tokens 5,734,400 | time 118.23s
# step 00800 | train loss 6.1212 | val loss 6.0987 | tok/s 48690 | tokens 6,553,600 | time 135.05s
# step 00900 | train loss 6.0597 | val loss 6.0845 | tok/s 48568 | tokens 7,372,800 | time 151.92s
# step 01000 | train loss 6.0165 | val loss 5.9958 | tok/s 48647 | tokens 8,192,000 | time 168.76s
# step 01100 | train loss 5.9939 | val loss 5.9541 | tok/s 48662 | tokens 9,011,200 | time 185.59s
# step 01200 | train loss 5.8728 | val loss 5.9148 | tok/s 48547 | tokens 9,830,400 | time 202.47s
# step 01300 | train loss 5.7631 | val loss 5.8347 | tok/s 48565 | tokens 10,649,600 | time 219.34s
# step 01400 | train loss 5.7991 | val loss 5.7898 | tok/s 48634 | tokens 11,468,800 | time 236.18s
# step 01500 | train loss 5.7241 | val loss 5.7688 | tok/s 48642 | tokens 12,288,000 | time 253.02s
# step 01600 | train loss 5.6094 | val loss 5.6870 | tok/s 48556 | tokens 13,107,200 | time 269.89s
# step 01700 | train loss 5.6721 | val loss 5.6247 | tok/s 48658 | tokens 13,926,400 | time 286.73s
# step 01800 | train loss 5.5791 | val loss 5.6362 | tok/s 48609 | tokens 14,745,600 | time 303.58s
# step 01900 | train loss 5.5777 | val loss 5.5149 | tok/s 48630 | tokens 15,564,800 | time 320.43s
# step 02000 | train loss 5.5631 | val loss 5.5781 | tok/s 48704 | tokens 16,384,000 | time 337.25s
# step 02100 | train loss 5.4831 | val loss 5.4531 | tok/s 48628 | tokens 17,203,200 | time 354.09s
# step 02200 | train loss 5.4329 | val loss 5.4057 | tok/s 48641 | tokens 18,022,400 | time 370.93s
# step 02300 | train loss 5.3819 | val loss 5.4683 | tok/s 48547 | tokens 18,841,600 | time 387.81s
# step 02400 | train loss 5.3463 | val loss 5.3628 | tok/s 48576 | tokens 19,660,800 | time 404.67s
# step 02500 | train loss 5.3385 | val loss 5.4185 | tok/s 48590 | tokens 20,480,000 | time 421.53s
# step 02600 | train loss 5.3460 | val loss 5.3837 | tok/s 48669 | tokens 21,299,200 | time 438.36s
# step 02700 | train loss 5.3181 | val loss 5.3468 | tok/s 48694 | tokens 22,118,400 | time 455.19s
# step 02800 | train loss 5.2282 | val loss 5.3046 | tok/s 48660 | tokens 22,937,600 | time 472.02s
# step 02900 | train loss 5.2583 | val loss 5.2897 | tok/s 48682 | tokens 23,756,800 | time 488.85s
# step 03000 | train loss 5.2293 | val loss 5.2247 | tok/s 48692 | tokens 24,576,000 | time 505.67s
# step 03100 | train loss 5.1618 | val loss 5.2078 | tok/s 48646 | tokens 25,395,200 | time 522.51s
# step 03200 | train loss 5.2125 | val loss 5.2409 | tok/s 48718 | tokens 26,214,400 | time 539.33s
# step 03300 | train loss 5.1507 | val loss 5.1939 | tok/s 48579 | tokens 27,033,600 | time 556.19s
# step 03400 | train loss 5.1243 | val loss 5.2270 | tok/s 48535 | tokens 27,852,800 | time 573.07s
# step 03500 | train loss 5.1289 | val loss 5.2190 | tok/s 48592 | tokens 28,672,000 | time 589.93s
# step 03600 | train loss 5.0914 | val loss 5.0530 | tok/s 48531 | tokens 29,491,200 | time 606.81s
# step 03700 | train loss 5.1528 | val loss 5.0828 | tok/s 48626 | tokens 30,310,400 | time 623.65s
# step 03800 | train loss 5.0499 | val loss 5.0872 | tok/s 48685 | tokens 31,129,600 | time 640.48s
# step 03900 | train loss 5.0407 | val loss 5.0783 | tok/s 48657 | tokens 31,948,800 | time 657.32s
# step 04000 | train loss 5.1154 | val loss 5.0009 | tok/s 48564 | tokens 32,768,000 | time 674.19s
# step 04100 | train loss 5.0055 | val loss 5.0890 | tok/s 48600 | tokens 33,587,200 | time 691.04s
# step 04200 | train loss 5.0410 | val loss 5.0562 | tok/s 48541 | tokens 34,406,400 | time 707.92s
# step 04300 | train loss 5.0777 | val loss 5.0957 | tok/s 48528 | tokens 35,225,600 | time 724.80s
# step 04400 | train loss 4.9849 | val loss 5.0244 | tok/s 48623 | tokens 36,044,800 | time 741.65s
# step 04500 | train loss 4.9536 | val loss 5.0301 | tok/s 48598 | tokens 36,864,000 | time 758.50s
# step 04600 | train loss 4.9310 | val loss 4.9855 | tok/s 48517 | tokens 37,683,200 | time 775.39s
# step 04700 | train loss 4.9130 | val loss 4.9335 | tok/s 48619 | tokens 38,502,400 | time 792.24s
# step 04800 | train loss 4.8918 | val loss 4.9360 | tok/s 48646 | tokens 39,321,600 | time 809.08s
# step 04900 | train loss 4.9293 | val loss 4.9103 | tok/s 48643 | tokens 40,140,800 | time 825.92s
# step 05000 | train loss 4.9846 | val loss 4.9309 | tok/s 48628 | tokens 40,960,000 | time 842.76s
# step 05100 | train loss 4.8976 | val loss 4.9053 | tok/s 48768 | tokens 41,779,200 | time 859.56s
# step 05200 | train loss 4.8766 | val loss 4.8832 | tok/s 48667 | tokens 42,598,400 | time 876.39s
# step 05300 | train loss 4.8487 | val loss 4.8786 | tok/s 48635 | tokens 43,417,600 | time 893.24s
# step 05400 | train loss 4.8474 | val loss 4.8637 | tok/s 48735 | tokens 44,236,800 | time 910.05s
# step 05500 | train loss 4.8288 | val loss 4.8919 | tok/s 48782 | tokens 45,056,000 | time 926.84s
# step 05600 | train loss 4.8241 | val loss 4.8026 | tok/s 48776 | tokens 45,875,200 | time 943.63s
# step 05700 | train loss 4.8184 | val loss 4.8240 | tok/s 48784 | tokens 46,694,400 | time 960.43s
# step 05800 | train loss 4.8060 | val loss 4.8534 | tok/s 48656 | tokens 47,513,600 | time 977.26s
# step 05900 | train loss 4.8143 | val loss 4.7848 | tok/s 48768 | tokens 48,332,800 | time 994.06s
# step 06000 | train loss 4.7479 | val loss 4.7963 | tok/s 48566 | tokens 49,152,000 | time 1010.93s
# step 06100 | train loss 4.7742 | val loss 4.7501 | tok/s 48657 | tokens 49,971,200 | time 1027.76s
# step 06200 | train loss 4.7124 | val loss 4.7847 | tok/s 48633 | tokens 50,790,400 | time 1044.61s
# step 06300 | train loss 4.6991 | val loss 4.8279 | tok/s 48755 | tokens 51,609,600 | time 1061.41s
# step 06400 | train loss 4.7371 | val loss 4.7391 | tok/s 48603 | tokens 52,428,800 | time 1078.26s
# step 06500 | train loss 4.7462 | val loss 4.7701 | tok/s 48636 | tokens 53,248,000 | time 1095.11s
# step 06600 | train loss 4.7048 | val loss 4.7365 | tok/s 48461 | tokens 54,067,200 | time 1112.01s
# step 06700 | train loss 4.7063 | val loss 4.7597 | tok/s 48718 | tokens 54,886,400 | time 1128.83s
# step 06800 | train loss 4.6991 | val loss 4.7474 | tok/s 48516 | tokens 55,705,600 | time 1145.71s
# step 06900 | train loss 4.6496 | val loss 4.7171 | tok/s 48736 | tokens 56,524,800 | time 1162.52s
# step 07000 | train loss 4.6210 | val loss 4.6429 | tok/s 48455 | tokens 57,344,000 | time 1179.43s
# step 07100 | train loss 4.6492 | val loss 4.7503 | tok/s 48454 | tokens 58,163,200 | time 1196.33s
# step 07200 | train loss 4.6730 | val loss 4.6832 | tok/s 48767 | tokens 58,982,400 | time 1213.13s
# step 07300 | train loss 4.6444 | val loss 4.7270 | tok/s 48619 | tokens 59,801,600 | time 1229.98s
# step 07400 | train loss 4.5966 | val loss 4.7417 | tok/s 48545 | tokens 60,620,800 | time 1246.86s
# step 07500 | train loss 4.6723 | val loss 4.7182 | tok/s 48577 | tokens 61,440,000 | time 1263.72s
# step 07600 | train loss 4.6231 | val loss 4.6736 | tok/s 48567 | tokens 62,259,200 | time 1280.59s
# step 07700 | train loss 4.6201 | val loss 4.6851 | tok/s 48583 | tokens 63,078,400 | time 1297.45s
# step 07800 | train loss 4.6177 | val loss 4.6437 | tok/s 48593 | tokens 63,897,600 | time 1314.31s
# step 07900 | train loss 4.6332 | val loss 4.6463 | tok/s 48656 | tokens 64,716,800 | time 1331.14s
# step 08000 | train loss 4.6224 | val loss 4.6869 | tok/s 48725 | tokens 65,536,000 | time 1347.96s
# step 08100 | train loss 4.5938 | val loss 4.6381 | tok/s 48651 | tokens 66,355,200 | time 1364.79s
# step 08200 | train loss 4.5592 | val loss 4.6807 | tok/s 48638 | tokens 67,174,400 | time 1381.64s
# step 08300 | train loss 4.5776 | val loss 4.6462 | tok/s 48588 | tokens 67,993,600 | time 1398.50s
# step 08400 | train loss 4.5823 | val loss 4.6419 | tok/s 48504 | tokens 68,812,800 | time 1415.39s
# step 08500 | train loss 4.5825 | val loss 4.6101 | tok/s 48650 | tokens 69,632,000 | time 1432.22s
# step 08600 | train loss 4.6213 | val loss 4.6272 | tok/s 48701 | tokens 70,451,200 | time 1449.05s
# step 08700 | train loss 4.5441 | val loss 4.6450 | tok/s 48728 | tokens 71,270,400 | time 1465.86s
# step 08800 | train loss 4.5442 | val loss 4.5951 | tok/s 48596 | tokens 72,089,600 | time 1482.71s
# step 08900 | train loss 4.5549 | val loss 4.6590 | tok/s 48704 | tokens 72,908,800 | time 1499.53s
# step 09000 | train loss 4.5514 | val loss 4.6358 | tok/s 48630 | tokens 73,728,000 | time 1516.38s
# step 09100 | train loss 4.5334 | val loss 4.5329 | tok/s 48675 | tokens 74,547,200 | time 1533.21s
# step 09200 | train loss 4.5009 | val loss 4.6107 | tok/s 48676 | tokens 75,366,400 | time 1550.04s
# step 09300 | train loss 4.5564 | val loss 4.5603 | tok/s 48622 | tokens 76,185,600 | time 1566.89s
# step 09400 | train loss 4.4840 | val loss 4.5688 | tok/s 48459 | tokens 77,004,800 | time 1583.79s
# step 09500 | train loss 4.4727 | val loss 4.5415 | tok/s 48392 | tokens 77,824,000 | time 1600.72s
# step 09600 | train loss 4.5296 | val loss 4.5877 | tok/s 48506 | tokens 78,643,200 | time 1617.61s
# step 09700 | train loss 4.4952 | val loss 4.5853 | tok/s 48506 | tokens 79,462,400 | time 1634.50s
# step 09800 | train loss 4.5460 | val loss 4.6014 | tok/s 48568 | tokens 80,281,600 | time 1651.36s
# step 09900 | train loss 4.5221 | val loss 4.5194 | tok/s 48449 | tokens 81,100,800 | time 1668.27s
# step 10000 | train loss 4.4979 | val loss 4.5743 | tok/s 48546 | tokens 81,920,000 | time 1685.15s
# step 10100 | train loss 4.5036 | val loss 4.5592 | tok/s 48623 | tokens 82,739,200 | time 1701.99s
# step 10200 | train loss 4.5130 | val loss 4.5687 | tok/s 48552 | tokens 83,558,400 | time 1718.87s
# step 10300 | train loss 4.4510 | val loss 4.5023 | tok/s 48536 | tokens 84,377,600 | time 1735.74s
# step 10400 | train loss 4.5402 | val loss 4.5490 | tok/s 48592 | tokens 85,196,800 | time 1752.60s
# step 10500 | train loss 4.4823 | val loss 4.4143 | tok/s 48566 | tokens 86,016,000 | time 1769.47s
# step 10600 | train loss 4.5062 | val loss 4.5005 | tok/s 48559 | tokens 86,835,200 | time 1786.34s
# step 10700 | train loss 4.4890 | val loss 4.5518 | tok/s 48540 | tokens 87,654,400 | time 1803.22s
# step 10800 | train loss 4.4803 | val loss 4.5175 | tok/s 48643 | tokens 88,473,600 | time 1820.06s
# step 10900 | train loss 4.4937 | val loss 4.5220 | tok/s 48709 | tokens 89,292,800 | time 1836.88s
# step 11000 | train loss 4.3947 | val loss 4.4808 | tok/s 48507 | tokens 90,112,000 | time 1853.76s
# step 11100 | train loss 4.4570 | val loss 4.4974 | tok/s 48647 | tokens 90,931,200 | time 1870.60s
# step 11200 | train loss 4.4728 | val loss 4.4364 | tok/s 48599 | tokens 91,750,400 | time 1887.46s
# step 11300 | train loss 4.4587 | val loss 4.4592 | tok/s 48483 | tokens 92,569,600 | time 1904.36s
# step 11400 | train loss 4.4058 | val loss 4.4968 | tok/s 48748 | tokens 93,388,800 | time 1921.16s
# step 11500 | train loss 4.4606 | val loss 4.4400 | tok/s 48721 | tokens 94,208,000 | time 1937.97s
# step 11600 | train loss 4.4430 | val loss 4.4910 | tok/s 48716 | tokens 95,027,200 | time 1954.79s
# step 11700 | train loss 4.3589 | val loss 4.4409 | tok/s 48550 | tokens 95,846,400 | time 1971.66s
# step 11800 | train loss 4.4767 | val loss 4.4613 | tok/s 48580 | tokens 96,665,600 | time 1988.53s
# step 11900 | train loss 4.4352 | val loss 4.5281 | tok/s 48522 | tokens 97,484,800 | time 2005.41s
# step 12000 | train loss 4.4698 | val loss 4.4295 | tok/s 48700 | tokens 98,304,000 | time 2022.23s
# step 12100 | train loss 4.4348 | val loss 4.4109 | tok/s 48708 | tokens 99,123,200 | time 2039.05s
# step 12200 | train loss 4.4359 | val loss 4.4705 | tok/s 48599 | tokens 99,942,400 | time 2055.90s
# step 12300 | train loss 4.4716 | val loss 4.3906 | tok/s 48608 | tokens 100,761,600 | time 2072.76s
# step 12400 | train loss 4.4229 | val loss 4.4022 | tok/s 48579 | tokens 101,580,800 | time 2089.62s
# step 12500 | train loss 4.3493 | val loss 4.3984 | tok/s 48715 | tokens 102,400,000 | time 2106.44s
# step 12600 | train loss 4.3932 | val loss 4.4554 | tok/s 48642 | tokens 103,219,200 | time 2123.28s
# step 12700 | train loss 4.4206 | val loss 4.3983 | tok/s 48674 | tokens 104,038,400 | time 2140.11s
# step 12800 | train loss 4.3840 | val loss 4.4597 | tok/s 48707 | tokens 104,857,600 | time 2156.93s
# step 12900 | train loss 4.3801 | val loss 4.4079 | tok/s 48735 | tokens 105,676,800 | time 2173.74s
# step 13000 | train loss 4.3735 | val loss 4.3971 | tok/s 48683 | tokens 106,496,000 | time 2190.56s
# step 13100 | train loss 4.3843 | val loss 4.4101 | tok/s 48627 | tokens 107,315,200 | time 2207.41s
# step 13200 | train loss 4.3701 | val loss 4.3910 | tok/s 48666 | tokens 108,134,400 | time 2224.24s
# step 13300 | train loss 4.3992 | val loss 4.4240 | tok/s 48613 | tokens 108,953,600 | time 2241.09s
# step 13400 | train loss 4.3886 | val loss 4.4715 | tok/s 48614 | tokens 109,772,800 | time 2257.94s
# step 13500 | train loss 4.3448 | val loss 4.4326 | tok/s 48571 | tokens 110,592,000 | time 2274.81s
# step 13600 | train loss 4.3616 | val loss 4.3727 | tok/s 48608 | tokens 111,411,200 | time 2291.66s
# step 13700 | train loss 4.3729 | val loss 4.3819 | tok/s 48676 | tokens 112,230,400 | time 2308.49s
# step 13800 | train loss 4.3656 | val loss 4.4304 | tok/s 48574 | tokens 113,049,600 | time 2325.36s
# step 13900 | train loss 4.3584 | val loss 4.3985 | tok/s 48777 | tokens 113,868,800 | time 2342.15s
# step 14000 | train loss 4.3951 | val loss 4.3521 | tok/s 48518 | tokens 114,688,000 | time 2359.04s
# step 14100 | train loss 4.3300 | val loss 4.4109 | tok/s 48624 | tokens 115,507,200 | time 2375.88s
# step 14200 | train loss 4.3457 | val loss 4.3610 | tok/s 48400 | tokens 116,326,400 | time 2392.81s
# step 14300 | train loss 4.3561 | val loss 4.3780 | tok/s 48551 | tokens 117,145,600 | time 2409.68s
# step 14400 | train loss 4.4085 | val loss 4.3981 | tok/s 48652 | tokens 117,964,800 | time 2426.52s
# step 14500 | train loss 4.3503 | val loss 4.3226 | tok/s 48682 | tokens 118,784,000 | time 2443.35s
# step 14600 | train loss 4.3926 | val loss 4.4118 | tok/s 48694 | tokens 119,603,200 | time 2460.17s
# step 14700 | train loss 4.3841 | val loss 4.4013 | tok/s 48579 | tokens 120,422,400 | time 2477.03s
# step 14800 | train loss 4.3426 | val loss 4.4141 | tok/s 48568 | tokens 121,241,600 | time 2493.90s
# step 14900 | train loss 4.3403 | val loss 4.3115 | tok/s 48695 | tokens 122,060,800 | time 2510.72s
# step 15000 | train loss 4.3351 | val loss 4.3284 | tok/s 48696 | tokens 122,880,000 | time 2527.55s
# step 15100 | train loss 4.3973 | val loss 4.3724 | tok/s 48796 | tokens 123,699,200 | time 2544.33s
# step 15200 | train loss 4.3185 | val loss 4.4102 | tok/s 48741 | tokens 124,518,400 | time 2561.14s
# step 15300 | train loss 4.3110 | val loss 4.4079 | tok/s 48667 | tokens 125,337,600 | time 2577.97s
# step 15400 | train loss 4.2698 | val loss 4.3612 | tok/s 48617 | tokens 126,156,800 | time 2594.82s
# step 15500 | train loss 4.3503 | val loss 4.3065 | tok/s 48680 | tokens 126,976,000 | time 2611.65s
# step 15600 | train loss 4.3253 | val loss 4.3386 | tok/s 48697 | tokens 127,795,200 | time 2628.47s
# step 15700 | train loss 4.3220 | val loss 4.3969 | tok/s 48720 | tokens 128,614,400 | time 2645.29s
# step 15800 | train loss 4.2944 | val loss 4.3459 | tok/s 48779 | tokens 129,433,600 | time 2662.08s
# step 15900 | train loss 4.2806 | val loss 4.3814 | tok/s 48521 | tokens 130,252,800 | time 2678.97s
# step 16000 | train loss 4.2993 | val loss 4.3919 | tok/s 48577 | tokens 131,072,000 | time 2695.83s
# step 16100 | train loss 4.3475 | val loss 4.3544 | tok/s 48626 | tokens 131,891,200 | time 2712.68s
# step 16200 | train loss 4.2538 | val loss 4.3706 | tok/s 48635 | tokens 132,710,400 | time 2729.52s
# step 16300 | train loss 4.2966 | val loss 4.2776 | tok/s 48595 | tokens 133,529,600 | time 2746.38s
# step 16400 | train loss 4.3356 | val loss 4.3148 | tok/s 48715 | tokens 134,348,800 | time 2763.19s
# step 16500 | train loss 4.2811 | val loss 4.3107 | tok/s 48634 | tokens 135,168,000 | time 2780.04s
# step 16600 | train loss 4.2785 | val loss 4.3376 | tok/s 48602 | tokens 135,987,200 | time 2796.89s
# step 16700 | train loss 4.3540 | val loss 4.2950 | tok/s 48706 | tokens 136,806,400 | time 2813.71s
# step 16800 | train loss 4.2785 | val loss 4.3421 | tok/s 48611 | tokens 137,625,600 | time 2830.56s
# step 16900 | train loss 4.3334 | val loss 4.3652 | tok/s 48782 | tokens 138,444,800 | time 2847.36s
# step 17000 | train loss 4.2432 | val loss 4.3423 | tok/s 48676 | tokens 139,264,000 | time 2864.19s
# step 17100 | train loss 4.3113 | val loss 4.2957 | tok/s 48534 | tokens 140,083,200 | time 2881.06s
# step 17200 | train loss 4.3299 | val loss 4.3006 | tok/s 48532 | tokens 140,902,400 | time 2897.94s
# step 17300 | train loss 4.2781 | val loss 4.2922 | tok/s 48509 | tokens 141,721,600 | time 2914.83s
# step 17400 | train loss 4.2565 | val loss 4.3273 | tok/s 48713 | tokens 142,540,800 | time 2931.65s
# step 17500 | train loss 4.3157 | val loss 4.3227 | tok/s 48576 | tokens 143,360,000 | time 2948.51s
# step 17600 | train loss 4.2732 | val loss 4.3044 | tok/s 48735 | tokens 144,179,200 | time 2965.32s
# step 17700 | train loss 4.2654 | val loss 4.3165 | tok/s 48712 | tokens 144,998,400 | time 2982.14s
# step 17800 | train loss 4.2894 | val loss 4.2548 | tok/s 48543 | tokens 145,817,600 | time 2999.01s
# step 17900 | train loss 4.2437 | val loss 4.3156 | tok/s 48571 | tokens 146,636,800 | time 3015.88s
# step 18000 | train loss 4.2600 | val loss 4.3750 | tok/s 48777 | tokens 147,456,000 | time 3032.67s
# step 18100 | train loss 4.2696 | val loss 4.3199 | tok/s 48685 | tokens 148,275,200 | time 3049.50s
# step 18200 | train loss 4.2996 | val loss 4.2998 | tok/s 48561 | tokens 149,094,400 | time 3066.37s
# step 18300 | train loss 4.2738 | val loss 4.2919 | tok/s 48649 | tokens 149,913,600 | time 3083.21s
# step 18400 | train loss 4.2801 | val loss 4.3114 | tok/s 48606 | tokens 150,732,800 | time 3100.06s
# step 18500 | train loss 4.2688 | val loss 4.3161 | tok/s 48629 | tokens 151,552,000 | time 3116.91s
# step 18600 | train loss 4.2684 | val loss 4.2386 | tok/s 48725 | tokens 152,371,200 | time 3133.72s
# step 18700 | train loss 4.1949 | val loss 4.2998 | tok/s 48800 | tokens 153,190,400 | time 3150.51s
# step 18800 | train loss 4.2248 | val loss 4.2771 | tok/s 48473 | tokens 154,009,600 | time 3167.41s
# step 18900 | train loss 4.2627 | val loss 4.2599 | tok/s 48590 | tokens 154,828,800 | time 3184.27s
# step 19000 | train loss 4.2445 | val loss 4.2884 | tok/s 48658 | tokens 155,648,000 | time 3201.10s
# step 19100 | train loss 4.2372 | val loss 4.2491 | tok/s 48570 | tokens 156,467,200 | time 3217.97s
# step 19200 | train loss 4.2177 | val loss 4.3166 | tok/s 48691 | tokens 157,286,400 | time 3234.79s
# step 19300 | train loss 4.2934 | val loss 4.2841 | tok/s 48646 | tokens 158,105,600 | time 3251.63s
# step 19400 | train loss 4.2871 | val loss 4.3016 | tok/s 48687 | tokens 158,924,800 | time 3268.46s
# step 19500 | train loss 4.2341 | val loss 4.2894 | tok/s 48725 | tokens 159,744,000 | time 3285.27s
# step 19600 | train loss 4.2654 | val loss 4.2750 | tok/s 48563 | tokens 160,563,200 | time 3302.14s
# step 19700 | train loss 4.2028 | val loss 4.2471 | tok/s 48593 | tokens 161,382,400 | time 3319.00s
# step 19800 | train loss 4.2102 | val loss 4.2336 | tok/s 48559 | tokens 162,201,600 | time 3335.87s
# step 19900 | train loss 4.2402 | val loss 4.2556 | tok/s 48613 | tokens 163,020,800 | time 3352.72s
# step 20000 | train loss 4.2449 | val loss 4.2666 | tok/s 48557 | tokens 163,840,000 | time 3369.59s
# step 20100 | train loss 4.2844 | val loss 4.2973 | tok/s 48641 | tokens 164,659,200 | time 3386.43s
# step 20200 | train loss 4.2344 | val loss 4.2362 | tok/s 48652 | tokens 165,478,400 | time 3403.27s
# step 20300 | train loss 4.2950 | val loss 4.3124 | tok/s 48670 | tokens 166,297,600 | time 3420.10s
# step 20400 | train loss 4.1918 | val loss 4.2451 | tok/s 48697 | tokens 167,116,800 | time 3436.92s
# step 20500 | train loss 4.3052 | val loss 4.2301 | tok/s 48566 | tokens 167,936,000 | time 3453.79s
# step 20600 | train loss 4.2274 | val loss 4.3020 | tok/s 48672 | tokens 168,755,200 | time 3470.62s
# step 20700 | train loss 4.2210 | val loss 4.3028 | tok/s 48717 | tokens 169,574,400 | time 3487.44s
# step 20800 | train loss 4.2012 | val loss 4.2772 | tok/s 48655 | tokens 170,393,600 | time 3504.27s
# step 20900 | train loss 4.2206 | val loss 4.2615 | tok/s 48639 | tokens 171,212,800 | time 3521.12s
# step 21000 | train loss 4.1861 | val loss 4.3023 | tok/s 48636 | tokens 172,032,000 | time 3537.96s
# step 21100 | train loss 4.2512 | val loss 4.2458 | tok/s 48577 | tokens 172,851,200 | time 3554.82s
# step 21200 | train loss 4.2007 | val loss 4.2483 | tok/s 48642 | tokens 173,670,400 | time 3571.66s
# step 21300 | train loss 4.2314 | val loss 4.2703 | tok/s 48585 | tokens 174,489,600 | time 3588.52s
# step 21400 | train loss 4.1975 | val loss 4.2638 | tok/s 48565 | tokens 175,308,800 | time 3605.39s
# step 21500 | train loss 4.1873 | val loss 4.2019 | tok/s 48520 | tokens 176,128,000 | time 3622.28s
# step 21600 | train loss 4.2517 | val loss 4.2620 | tok/s 48560 | tokens 176,947,200 | time 3639.15s
# step 21700 | train loss 4.1835 | val loss 4.2374 | tok/s 48648 | tokens 177,766,400 | time 3655.98s
# step 21800 | train loss 4.1704 | val loss 4.2980 | tok/s 48521 | tokens 178,585,600 | time 3672.87s
# step 21900 | train loss 4.1571 | val loss 4.3011 | tok/s 48696 | tokens 179,404,800 | time 3689.69s
# step 22000 | train loss 4.2889 | val loss 4.2819 | tok/s 48673 | tokens 180,224,000 | time 3706.52s
# step 22100 | train loss 4.2322 | val loss 4.2503 | tok/s 48707 | tokens 181,043,200 | time 3723.34s
# step 22200 | train loss 4.2220 | val loss 4.2724 | tok/s 48620 | tokens 181,862,400 | time 3740.19s
# step 22300 | train loss 4.2058 | val loss 4.2557 | tok/s 48728 | tokens 182,681,600 | time 3757.00s
# step 22400 | train loss 4.1831 | val loss 4.2562 | tok/s 48566 | tokens 183,500,800 | time 3773.87s
# step 22500 | train loss 4.1538 | val loss 4.2461 | tok/s 48515 | tokens 184,320,000 | time 3790.75s
# step 22600 | train loss 4.1637 | val loss 4.2126 | tok/s 48558 | tokens 185,139,200 | time 3807.62s
# step 22700 | train loss 4.1426 | val loss 4.2182 | tok/s 48581 | tokens 185,958,400 | time 3824.49s
# step 22800 | train loss 4.2038 | val loss 4.2371 | tok/s 48589 | tokens 186,777,600 | time 3841.35s
# step 22900 | train loss 4.2110 | val loss 4.2798 | tok/s 48619 | tokens 187,596,800 | time 3858.19s
# step 23000 | train loss 4.2078 | val loss 4.1765 | tok/s 48666 | tokens 188,416,000 | time 3875.03s
# step 23100 | train loss 4.1426 | val loss 4.2098 | tok/s 48578 | tokens 189,235,200 | time 3891.89s
# step 23200 | train loss 4.1013 | val loss 4.2334 | tok/s 48717 | tokens 190,054,400 | time 3908.71s
# step 23300 | train loss 4.1247 | val loss 4.2848 | tok/s 48580 | tokens 190,873,600 | time 3925.57s
# step 23400 | train loss 4.1771 | val loss 4.2031 | tok/s 48478 | tokens 191,692,800 | time 3942.47s
# step 23500 | train loss 4.1994 | val loss 4.1949 | tok/s 48645 | tokens 192,512,000 | time 3959.31s
# step 23600 | train loss 4.1787 | val loss 4.2134 | tok/s 48596 | tokens 193,331,200 | time 3976.16s
# step 23700 | train loss 4.1776 | val loss 4.2338 | tok/s 48644 | tokens 194,150,400 | time 3993.01s
# step 23800 | train loss 4.2037 | val loss 4.2388 | tok/s 48608 | tokens 194,969,600 | time 4009.86s
# step 23900 | train loss 4.1787 | val loss 4.2155 | tok/s 48652 | tokens 195,788,800 | time 4026.70s
# step 24000 | train loss 4.1718 | val loss 4.2048 | tok/s 48617 | tokens 196,608,000 | time 4043.55s
# step 24100 | train loss 4.1337 | val loss 4.1753 | tok/s 48619 | tokens 197,427,200 | time 4060.40s
# step 24200 | train loss 4.2127 | val loss 4.1762 | tok/s 48569 | tokens 198,246,400 | time 4077.26s
# step 24300 | train loss 4.0968 | val loss 4.1722 | tok/s 48530 | tokens 199,065,600 | time 4094.14s
# step 24400 | train loss 4.1782 | val loss 4.1728 | tok/s 48596 | tokens 199,884,800 | time 4111.00s
# step 24500 | train loss 4.1414 | val loss 4.1957 | tok/s 48596 | tokens 200,704,000 | time 4127.86s
# step 24600 | train loss 4.2265 | val loss 4.1884 | tok/s 48568 | tokens 201,523,200 | time 4144.72s
# step 24700 | train loss 4.1668 | val loss 4.2147 | tok/s 48594 | tokens 202,342,400 | time 4161.58s
# step 24800 | train loss 4.1670 | val loss 4.2160 | tok/s 48632 | tokens 203,161,600 | time 4178.43s
# step 24900 | train loss 4.1315 | val loss 4.2164 | tok/s 48634 | tokens 203,980,800 | time 4195.27s
# step 25000 | train loss 4.1721 | val loss 4.2234 | tok/s 48555 | tokens 204,800,000 | time 4212.14s
# step 25100 | train loss 4.1471 | val loss 4.2426 | tok/s 48549 | tokens 205,619,200 | time 4229.01s
# step 25200 | train loss 4.1940 | val loss 4.1594 | tok/s 48638 | tokens 206,438,400 | time 4245.86s
# step 25300 | train loss 4.1423 | val loss 4.1951 | tok/s 48587 | tokens 207,257,600 | time 4262.72s
# step 25400 | train loss 4.1812 | val loss 4.2074 | tok/s 48590 | tokens 208,076,800 | time 4279.58s
# step 25500 | train loss 4.1400 | val loss 4.1818 | tok/s 48556 | tokens 208,896,000 | time 4296.45s
# step 25600 | train loss 4.1539 | val loss 4.1740 | tok/s 48647 | tokens 209,715,200 | time 4313.29s
# step 25700 | train loss 4.1810 | val loss 4.1670 | tok/s 48598 | tokens 210,534,400 | time 4330.14s
# step 25800 | train loss 4.1545 | val loss 4.1779 | tok/s 48757 | tokens 211,353,600 | time 4346.94s
# step 25900 | train loss 4.1360 | val loss 4.2289 | tok/s 48666 | tokens 212,172,800 | time 4363.78s
# step 26000 | train loss 4.1499 | val loss 4.2005 | tok/s 48674 | tokens 212,992,000 | time 4380.61s
# step 26100 | train loss 4.1616 | val loss 4.1538 | tok/s 48712 | tokens 213,811,200 | time 4397.43s
# step 26200 | train loss 4.1233 | val loss 4.1686 | tok/s 48701 | tokens 214,630,400 | time 4414.25s
# step 26300 | train loss 4.1391 | val loss 4.2166 | tok/s 48691 | tokens 215,449,600 | time 4431.07s
# step 26400 | train loss 4.1726 | val loss 4.1715 | tok/s 48744 | tokens 216,268,800 | time 4447.88s
# step 26500 | train loss 4.1641 | val loss 4.2073 | tok/s 48619 | tokens 217,088,000 | time 4464.73s
# step 26600 | train loss 4.1232 | val loss 4.2272 | tok/s 48601 | tokens 217,907,200 | time 4481.58s
# step 26700 | train loss 4.1091 | val loss 4.1744 | tok/s 48769 | tokens 218,726,400 | time 4498.38s
# step 26800 | train loss 4.1252 | val loss 4.2147 | tok/s 48765 | tokens 219,545,600 | time 4515.18s
# step 26900 | train loss 4.0770 | val loss 4.2158 | tok/s 48865 | tokens 220,364,800 | time 4531.94s
# step 27000 | train loss 4.1359 | val loss 4.2017 | tok/s 48846 | tokens 221,184,000 | time 4548.71s
# step 27100 | train loss 4.1022 | val loss 4.1576 | tok/s 48745 | tokens 222,003,200 | time 4565.52s
# step 27200 | train loss 4.1285 | val loss 4.1912 | tok/s 48792 | tokens 222,822,400 | time 4582.31s
# step 27300 | train loss 4.0522 | val loss 4.1439 | tok/s 48658 | tokens 223,641,600 | time 4599.14s
# step 27400 | train loss 4.1223 | val loss 4.1779 | tok/s 48688 | tokens 224,460,800 | time 4615.97s
# step 27500 | train loss 4.1127 | val loss 4.1338 | tok/s 48468 | tokens 225,280,000 | time 4632.87s
# step 27600 | train loss 4.1159 | val loss 4.1609 | tok/s 48583 | tokens 226,099,200 | time 4649.73s
# step 27700 | train loss 4.1601 | val loss 4.1349 | tok/s 48496 | tokens 226,918,400 | time 4666.62s
# step 27800 | train loss 4.1732 | val loss 4.1664 | tok/s 48550 | tokens 227,737,600 | time 4683.50s
# step 27900 | train loss 4.1432 | val loss 4.1721 | tok/s 48596 | tokens 228,556,800 | time 4700.35s
# step 28000 | train loss 4.1060 | val loss 4.2761 | tok/s 48612 | tokens 229,376,000 | time 4717.21s
# step 28100 | train loss 4.1122 | val loss 4.1701 | tok/s 48559 | tokens 230,195,200 | time 4734.08s
# step 28200 | train loss 4.1332 | val loss 4.2180 | tok/s 48552 | tokens 231,014,400 | time 4750.95s
# step 28300 | train loss 4.1594 | val loss 4.2382 | tok/s 48534 | tokens 231,833,600 | time 4767.83s
# step 28400 | train loss 4.1403 | val loss 4.1095 | tok/s 48664 | tokens 232,652,800 | time 4784.66s
# step 28500 | train loss 4.1493 | val loss 4.1790 | tok/s 48516 | tokens 233,472,000 | time 4801.55s
# step 28600 | train loss 4.1191 | val loss 4.1759 | tok/s 48643 | tokens 234,291,200 | time 4818.39s
# step 28700 | train loss 4.1239 | val loss 4.1556 | tok/s 48657 | tokens 235,110,400 | time 4835.22s
# step 28800 | train loss 4.1238 | val loss 4.1659 | tok/s 48586 | tokens 235,929,600 | time 4852.08s
# step 28900 | train loss 4.1356 | val loss 4.1563 | tok/s 48595 | tokens 236,748,800 | time 4868.94s
# step 29000 | train loss 4.1175 | val loss 4.1945 | tok/s 48587 | tokens 237,568,000 | time 4885.80s
# step 29100 | train loss 4.1621 | val loss 4.1888 | tok/s 48642 | tokens 238,387,200 | time 4902.64s
# step 29200 | train loss 4.1775 | val loss 4.1677 | tok/s 48560 | tokens 239,206,400 | time 4919.51s
# step 29300 | train loss 4.1083 | val loss 4.1855 | tok/s 48520 | tokens 240,025,600 | time 4936.40s
# step 29400 | train loss 4.0829 | val loss 4.1488 | tok/s 48598 | tokens 240,844,800 | time 4953.25s
# step 29500 | train loss 4.0868 | val loss 4.1016 | tok/s 48515 | tokens 241,664,000 | time 4970.14s
# step 29600 | train loss 4.1209 | val loss 4.1486 | tok/s 48581 | tokens 242,483,200 | time 4987.00s
# step 29700 | train loss 4.1280 | val loss 4.1531 | tok/s 48585 | tokens 243,302,400 | time 5003.86s
# step 29800 | train loss 4.0780 | val loss 4.2218 | tok/s 48639 | tokens 244,121,600 | time 5020.70s
# step 29900 | train loss 4.0839 | val loss 4.1156 | tok/s 48647 | tokens 244,940,800 | time 5037.54s
# step 30000 | train loss 4.1015 | val loss 4.1329 | tok/s 48656 | tokens 245,760,000 | time 5054.38s
# step 30100 | train loss 4.1166 | val loss 4.1906 | tok/s 48545 | tokens 246,579,200 | time 5071.25s
# step 30200 | train loss 4.1379 | val loss 4.1425 | tok/s 48564 | tokens 247,398,400 | time 5088.12s
# step 30300 | train loss 4.0738 | val loss 4.1612 | tok/s 48529 | tokens 248,217,600 | time 5105.00s
# step 30400 | train loss 4.1082 | val loss 4.1872 | tok/s 48556 | tokens 249,036,800 | time 5121.87s
# step 30500 | train loss 4.0547 | val loss 4.2082 | tok/s 48551 | tokens 249,856,000 | time 5138.75s
# step 30600 | train loss 4.0879 | val loss 4.1367 | tok/s 48710 | tokens 250,675,200 | time 5155.56s
# step 30700 | train loss 4.1062 | val loss 4.1113 | tok/s 48590 | tokens 251,494,400 | time 5172.42s
# step 30800 | train loss 4.0748 | val loss 4.1201 | tok/s 48594 | tokens 252,313,600 | time 5189.28s
# step 30900 | train loss 4.0910 | val loss 4.1481 | tok/s 48713 | tokens 253,132,800 | time 5206.10s
# step 31000 | train loss 4.0565 | val loss 4.1735 | tok/s 48592 | tokens 253,952,000 | time 5222.96s
# step 31100 | train loss 4.1013 | val loss 4.1778 | tok/s 48340 | tokens 254,771,200 | time 5239.90s
# step 31200 | train loss 4.0543 | val loss 4.1461 | tok/s 48354 | tokens 255,590,400 | time 5256.84s
# step 31300 | train loss 4.1147 | val loss 4.1795 | tok/s 48479 | tokens 256,409,600 | time 5273.74s
# step 31400 | train loss 4.1460 | val loss 4.1496 | tok/s 48467 | tokens 257,228,800 | time 5290.64s
# step 31500 | train loss 4.0873 | val loss 4.0796 | tok/s 48474 | tokens 258,048,000 | time 5307.54s
# step 31600 | train loss 4.1320 | val loss 4.1342 | tok/s 48502 | tokens 258,867,200 | time 5324.43s
# step 31700 | train loss 4.1380 | val loss 4.1274 | tok/s 48517 | tokens 259,686,400 | time 5341.32s
# step 31800 | train loss 4.1125 | val loss 4.1239 | tok/s 48506 | tokens 260,505,600 | time 5358.21s
# step 31900 | train loss 4.0550 | val loss 4.1580 | tok/s 48469 | tokens 261,324,800 | time 5375.11s
# step 32000 | train loss 3.9940 | val loss 4.1588 | tok/s 48484 | tokens 262,144,000 | time 5392.00s
# step 32100 | train loss 4.1148 | val loss 4.1362 | tok/s 48507 | tokens 262,963,200 | time 5408.89s
# step 32200 | train loss 4.1057 | val loss 4.1475 | tok/s 48456 | tokens 263,782,400 | time 5425.80s
# step 32300 | train loss 4.0730 | val loss 4.1216 | tok/s 48578 | tokens 264,601,600 | time 5442.66s
# step 32400 | train loss 4.1093 | val loss 4.1631 | tok/s 48450 | tokens 265,420,800 | time 5459.57s
# step 32500 | train loss 4.0576 | val loss 4.1278 | tok/s 48480 | tokens 266,240,000 | time 5476.47s
# step 32600 | train loss 4.0806 | val loss 4.1243 | tok/s 48512 | tokens 267,059,200 | time 5493.35s
# step 32700 | train loss 4.0990 | val loss 4.2004 | tok/s 48645 | tokens 267,878,400 | time 5510.19s
# step 32800 | train loss 4.1311 | val loss 4.1604 | tok/s 48532 | tokens 268,697,600 | time 5527.07s
# step 32900 | train loss 4.0801 | val loss 4.1553 | tok/s 48514 | tokens 269,516,800 | time 5543.96s
# step 33000 | train loss 4.0891 | val loss 4.1252 | tok/s 48467 | tokens 270,336,000 | time 5560.86s
# step 33100 | train loss 4.0679 | val loss 4.0394 | tok/s 48464 | tokens 271,155,200 | time 5577.76s
# step 33200 | train loss 4.0438 | val loss 4.1180 | tok/s 48626 | tokens 271,974,400 | time 5594.61s
# step 33300 | train loss 4.0621 | val loss 4.0910 | tok/s 48761 | tokens 272,793,600 | time 5611.41s
# step 33400 | train loss 4.0822 | val loss 4.0647 | tok/s 48671 | tokens 273,612,800 | time 5628.24s
# step 33500 | train loss 4.0229 | val loss 4.1593 | tok/s 48699 | tokens 274,432,000 | time 5645.06s
# step 33600 | train loss 4.0596 | val loss 4.1516 | tok/s 48684 | tokens 275,251,200 | time 5661.89s
# step 33700 | train loss 4.0264 | val loss 4.1056 | tok/s 48650 | tokens 276,070,400 | time 5678.73s
# step 33800 | train loss 4.0452 | val loss 4.0972 | tok/s 48702 | tokens 276,889,600 | time 5695.55s
# step 33900 | train loss 4.1441 | val loss 4.1655 | tok/s 48695 | tokens 277,708,800 | time 5712.37s
# step 34000 | train loss 4.0451 | val loss 4.0708 | tok/s 48741 | tokens 278,528,000 | time 5729.18s
# step 34100 | train loss 4.0460 | val loss 4.0727 | tok/s 48603 | tokens 279,347,200 | time 5746.03s
# step 34200 | train loss 4.1051 | val loss 4.1369 | tok/s 48413 | tokens 280,166,400 | time 5762.95s
# step 34300 | train loss 4.0847 | val loss 4.1761 | tok/s 48629 | tokens 280,985,600 | time 5779.80s
# step 34400 | train loss 4.0710 | val loss 4.2067 | tok/s 48728 | tokens 281,804,800 | time 5796.61s
# step 34500 | train loss 4.0143 | val loss 4.1083 | tok/s 48691 | tokens 282,624,000 | time 5813.44s
# step 34600 | train loss 4.0816 | val loss 4.1564 | tok/s 48469 | tokens 283,443,200 | time 5830.34s
# step 34700 | train loss 4.1159 | val loss 4.1675 | tok/s 48684 | tokens 284,262,400 | time 5847.16s
# step 34800 | train loss 4.0618 | val loss 4.1242 | tok/s 48646 | tokens 285,081,600 | time 5864.00s
# step 34900 | train loss 4.0256 | val loss 4.1171 | tok/s 48691 | tokens 285,900,800 | time 5880.83s
# step 35000 | train loss 4.0307 | val loss 4.0369 | tok/s 48608 | tokens 286,720,000 | time 5897.68s
# step 35100 | train loss 4.0813 | val loss 4.0793 | tok/s 48730 | tokens 287,539,200 | time 5914.49s
# step 35200 | train loss 4.0268 | val loss 4.1043 | tok/s 48699 | tokens 288,358,400 | time 5931.31s
# step 35300 | train loss 4.0462 | val loss 4.0718 | tok/s 48818 | tokens 289,177,600 | time 5948.09s
# step 35400 | train loss 4.0519 | val loss 4.0957 | tok/s 48612 | tokens 289,996,800 | time 5964.95s
# step 35500 | train loss 4.0546 | val loss 4.0900 | tok/s 48662 | tokens 290,816,000 | time 5981.78s
# step 35600 | train loss 4.0383 | val loss 4.1337 | tok/s 48702 | tokens 291,635,200 | time 5998.60s
# step 35700 | train loss 4.0624 | val loss 4.1320 | tok/s 48704 | tokens 292,454,400 | time 6015.42s
# step 35800 | train loss 4.0222 | val loss 4.0850 | tok/s 48648 | tokens 293,273,600 | time 6032.26s
# step 35900 | train loss 4.0639 | val loss 4.1492 | tok/s 48614 | tokens 294,092,800 | time 6049.11s
# step 36000 | train loss 4.0152 | val loss 4.1157 | tok/s 48605 | tokens 294,912,000 | time 6065.96s
# step 36100 | train loss 4.0997 | val loss 4.0965 | tok/s 48615 | tokens 295,731,200 | time 6082.81s
# step 36200 | train loss 4.0918 | val loss 4.1131 | tok/s 48658 | tokens 296,550,400 | time 6099.65s
# step 36300 | train loss 3.9974 | val loss 4.0891 | tok/s 48656 | tokens 297,369,600 | time 6116.49s
# step 36400 | train loss 4.1006 | val loss 4.0946 | tok/s 48685 | tokens 298,188,800 | time 6133.31s
# step 36500 | train loss 4.0373 | val loss 4.0872 | tok/s 48506 | tokens 299,008,000 | time 6150.20s
# step 36600 | train loss 4.0887 | val loss 4.1547 | tok/s 48592 | tokens 299,827,200 | time 6167.06s
# step 36700 | train loss 4.0231 | val loss 4.0993 | tok/s 48567 | tokens 300,646,400 | time 6183.93s
# step 36800 | train loss 4.0809 | val loss 4.1007 | tok/s 48637 | tokens 301,465,600 | time 6200.77s
# step 36900 | train loss 4.0366 | val loss 4.0630 | tok/s 48630 | tokens 302,284,800 | time 6217.62s
# step 37000 | train loss 4.0143 | val loss 4.1597 | tok/s 48471 | tokens 303,104,000 | time 6234.52s
# step 37100 | train loss 4.0419 | val loss 4.0372 | tok/s 48543 | tokens 303,923,200 | time 6251.39s
# step 37200 | train loss 4.1024 | val loss 4.0893 | tok/s 48371 | tokens 304,742,400 | time 6268.33s
# step 37300 | train loss 4.0131 | val loss 4.1317 | tok/s 48561 | tokens 305,561,600 | time 6285.20s
# step 37400 | train loss 4.1678 | val loss 4.0628 | tok/s 48621 | tokens 306,380,800 | time 6302.05s
# step 37500 | train loss 4.0695 | val loss 4.1288 | tok/s 48598 | tokens 307,200,000 | time 6318.90s
# step 37600 | train loss 4.0913 | val loss 4.0992 | tok/s 48584 | tokens 308,019,200 | time 6335.76s
# step 37700 | train loss 4.0419 | val loss 4.0950 | tok/s 48561 | tokens 308,838,400 | time 6352.63s
# step 37800 | train loss 4.0244 | val loss 4.1105 | tok/s 48550 | tokens 309,657,600 | time 6369.51s
# step 37900 | train loss 3.9861 | val loss 4.0671 | tok/s 48541 | tokens 310,476,800 | time 6386.38s
# step 38000 | train loss 4.0318 | val loss 4.1211 | tok/s 48518 | tokens 311,296,000 | time 6403.27s
# step 38100 | train loss 4.0034 | val loss 4.1278 | tok/s 48591 | tokens 312,115,200 | time 6420.12s
# step 38200 | train loss 3.9726 | val loss 4.0647 | tok/s 48594 | tokens 312,934,400 | time 6436.98s
# step 38300 | train loss 4.0681 | val loss 4.0923 | tok/s 48322 | tokens 313,753,600 | time 6453.94s
# step 38400 | train loss 4.0756 | val loss 4.0709 | tok/s 48638 | tokens 314,572,800 | time 6470.78s
# step 38500 | train loss 4.0188 | val loss 4.1214 | tok/s 48545 | tokens 315,392,000 | time 6487.65s
# step 38600 | train loss 4.0404 | val loss 4.1086 | tok/s 48597 | tokens 316,211,200 | time 6504.51s
# step 38700 | train loss 4.0517 | val loss 4.1325 | tok/s 48614 | tokens 317,030,400 | time 6521.36s
# step 38800 | train loss 4.0284 | val loss 4.0774 | tok/s 48495 | tokens 317,849,600 | time 6538.25s
# step 38900 | train loss 4.0878 | val loss 4.0532 | tok/s 48561 | tokens 318,668,800 | time 6555.12s
# step 39000 | train loss 4.0371 | val loss 4.0907 | tok/s 48664 | tokens 319,488,000 | time 6571.96s
# step 39100 | train loss 4.0749 | val loss 4.0508 | tok/s 48667 | tokens 320,307,200 | time 6588.79s
# step 39200 | train loss 4.0311 | val loss 4.1187 | tok/s 48720 | tokens 321,126,400 | time 6605.60s
# step 39300 | train loss 4.0678 | val loss 4.0405 | tok/s 48665 | tokens 321,945,600 | time 6622.44s
# step 39400 | train loss 4.0748 | val loss 4.0892 | tok/s 48731 | tokens 322,764,800 | time 6639.25s
# step 39500 | train loss 4.0394 | val loss 4.1248 | tok/s 48622 | tokens 323,584,000 | time 6656.10s
# step 39600 | train loss 4.0365 | val loss 4.0545 | tok/s 48452 | tokens 324,403,200 | time 6673.00s
# step 39700 | train loss 4.0264 | val loss 4.0899 | tok/s 48663 | tokens 325,222,400 | time 6689.84s
# step 39800 | train loss 3.9803 | val loss 4.0795 | tok/s 48619 | tokens 326,041,600 | time 6706.69s
# step 39900 | train loss 3.9950 | val loss 4.0320 | tok/s 48528 | tokens 326,860,800 | time 6723.57s
# step 40000 | train loss 4.0755 | val loss 4.0750 | tok/s 48612 | tokens 327,680,000 | time 6740.42s
# step 40100 | train loss 4.0310 | val loss 4.0792 | tok/s 48573 | tokens 328,499,200 | time 6757.28s
# step 40200 | train loss 4.0608 | val loss 4.1038 | tok/s 48487 | tokens 329,318,400 | time 6774.18s
# step 40300 | train loss 4.0135 | val loss 4.1419 | tok/s 48597 | tokens 330,137,600 | time 6791.04s
# step 40400 | train loss 4.0859 | val loss 4.1644 | tok/s 48646 | tokens 330,956,800 | time 6807.88s
# step 40500 | train loss 4.0259 | val loss 4.0573 | tok/s 48572 | tokens 331,776,000 | time 6824.74s
# step 40600 | train loss 4.0249 | val loss 4.1087 | tok/s 48728 | tokens 332,595,200 | time 6841.55s
# step 40700 | train loss 4.0576 | val loss 4.0656 | tok/s 48484 | tokens 333,414,400 | time 6858.45s
# step 40800 | train loss 3.9901 | val loss 4.0567 | tok/s 48680 | tokens 334,233,600 | time 6875.28s
# step 40900 | train loss 3.9860 | val loss 4.0855 | tok/s 48531 | tokens 335,052,800 | time 6892.16s
# step 41000 | train loss 4.0150 | val loss 4.1009 | tok/s 48629 | tokens 335,872,000 | time 6909.00s
# step 41100 | train loss 4.0267 | val loss 4.0885 | tok/s 48715 | tokens 336,691,200 | time 6925.82s
# step 41200 | train loss 4.0495 | val loss 4.0601 | tok/s 48707 | tokens 337,510,400 | time 6942.64s
# step 41300 | train loss 4.0393 | val loss 4.0818 | tok/s 48480 | tokens 338,329,600 | time 6959.54s
# step 41400 | train loss 4.0175 | val loss 4.0798 | tok/s 48628 | tokens 339,148,800 | time 6976.38s
# step 41500 | train loss 3.9984 | val loss 4.0973 | tok/s 48496 | tokens 339,968,000 | time 6993.27s
# step 41600 | train loss 3.9821 | val loss 4.0627 | tok/s 48497 | tokens 340,787,200 | time 7010.16s
# step 41700 | train loss 4.0026 | val loss 4.0598 | tok/s 48689 | tokens 341,606,400 | time 7026.99s
# step 41800 | train loss 4.0153 | val loss 4.0700 | tok/s 48560 | tokens 342,425,600 | time 7043.86s
# step 41900 | train loss 3.9948 | val loss 4.1363 | tok/s 48532 | tokens 343,244,800 | time 7060.74s
# step 42000 | train loss 4.0759 | val loss 4.0419 | tok/s 48553 | tokens 344,064,000 | time 7077.61s
# step 42100 | train loss 3.9932 | val loss 4.0883 | tok/s 48643 | tokens 344,883,200 | time 7094.45s
# step 42200 | train loss 3.9979 | val loss 4.0807 | tok/s 48514 | tokens 345,702,400 | time 7111.34s
# step 42300 | train loss 4.0058 | val loss 4.0880 | tok/s 48623 | tokens 346,521,600 | time 7128.19s
# step 42400 | train loss 4.0340 | val loss 4.0732 | tok/s 48674 | tokens 347,340,800 | time 7145.02s
# step 42500 | train loss 4.0491 | val loss 4.0671 | tok/s 48496 | tokens 348,160,000 | time 7161.91s
# step 42600 | train loss 4.0194 | val loss 4.0901 | tok/s 48553 | tokens 348,979,200 | time 7178.78s
# step 42700 | train loss 4.0453 | val loss 4.0302 | tok/s 48583 | tokens 349,798,400 | time 7195.64s
# step 42800 | train loss 3.9853 | val loss 4.0764 | tok/s 48754 | tokens 350,617,600 | time 7212.44s
# step 42900 | train loss 4.0395 | val loss 4.0294 | tok/s 48635 | tokens 351,436,800 | time 7229.29s
# step 43000 | train loss 3.9900 | val loss 4.0173 | tok/s 48669 | tokens 352,256,000 | time 7246.12s
# step 43100 | train loss 3.9821 | val loss 4.0152 | tok/s 48643 | tokens 353,075,200 | time 7262.96s
# step 43200 | train loss 3.9950 | val loss 4.0066 | tok/s 48547 | tokens 353,894,400 | time 7279.84s
# step 43300 | train loss 3.9830 | val loss 4.1040 | tok/s 48585 | tokens 354,713,600 | time 7296.70s
# step 43400 | train loss 4.0105 | val loss 4.1331 | tok/s 48554 | tokens 355,532,800 | time 7313.57s
# step 43500 | train loss 3.9522 | val loss 4.0660 | tok/s 48618 | tokens 356,352,000 | time 7330.42s
# step 43600 | train loss 3.9886 | val loss 4.0190 | tok/s 48559 | tokens 357,171,200 | time 7347.29s
# step 43700 | train loss 4.0600 | val loss 4.0395 | tok/s 48686 | tokens 357,990,400 | time 7364.11s
# step 43800 | train loss 3.9920 | val loss 4.0423 | tok/s 48618 | tokens 358,809,600 | time 7380.96s
# step 43900 | train loss 3.9271 | val loss 4.0882 | tok/s 48557 | tokens 359,628,800 | time 7397.83s
# step 44000 | train loss 4.0134 | val loss 4.1234 | tok/s 48469 | tokens 360,448,000 | time 7414.74s
# step 44100 | train loss 4.0616 | val loss 4.1023 | tok/s 48583 | tokens 361,267,200 | time 7431.60s
# step 44200 | train loss 4.0162 | val loss 4.0859 | tok/s 48650 | tokens 362,086,400 | time 7448.44s
# step 44300 | train loss 4.0560 | val loss 4.0910 | tok/s 48727 | tokens 362,905,600 | time 7465.25s
# step 44400 | train loss 4.0018 | val loss 4.0227 | tok/s 48647 | tokens 363,724,800 | time 7482.09s
# step 44500 | train loss 4.0433 | val loss 4.0209 | tok/s 48596 | tokens 364,544,000 | time 7498.94s
# step 44600 | train loss 4.0002 | val loss 4.0700 | tok/s 48583 | tokens 365,363,200 | time 7515.81s
# step 44700 | train loss 3.9947 | val loss 4.0452 | tok/s 48529 | tokens 366,182,400 | time 7532.69s
# step 44800 | train loss 4.0004 | val loss 4.0891 | tok/s 48566 | tokens 367,001,600 | time 7549.55s
# step 44900 | train loss 4.0122 | val loss 4.0411 | tok/s 48564 | tokens 367,820,800 | time 7566.42s
# step 45000 | train loss 4.0075 | val loss 4.0088 | tok/s 48591 | tokens 368,640,000 | time 7583.28s
# step 45100 | train loss 4.0519 | val loss 4.0749 | tok/s 48572 | tokens 369,459,200 | time 7600.15s
# step 45200 | train loss 3.9847 | val loss 4.1227 | tok/s 48672 | tokens 370,278,400 | time 7616.98s
# step 45300 | train loss 4.0141 | val loss 4.0286 | tok/s 48481 | tokens 371,097,600 | time 7633.87s
# step 45400 | train loss 4.0298 | val loss 4.0316 | tok/s 48502 | tokens 371,916,800 | time 7650.76s
# step 45500 | train loss 3.9997 | val loss 4.0437 | tok/s 48601 | tokens 372,736,000 | time 7667.62s
# step 45600 | train loss 4.0686 | val loss 4.0346 | tok/s 48609 | tokens 373,555,200 | time 7684.47s
# step 45700 | train loss 4.0115 | val loss 4.0456 | tok/s 48568 | tokens 374,374,400 | time 7701.34s
# step 45800 | train loss 4.0470 | val loss 4.0620 | tok/s 48628 | tokens 375,193,600 | time 7718.19s
# step 45900 | train loss 3.9998 | val loss 4.0962 | tok/s 48707 | tokens 376,012,800 | time 7735.00s
# step 46000 | train loss 3.9739 | val loss 4.0814 | tok/s 48622 | tokens 376,832,000 | time 7751.85s
# step 46100 | train loss 4.0175 | val loss 4.0156 | tok/s 48659 | tokens 377,651,200 | time 7768.69s
# step 46200 | train loss 3.9968 | val loss 4.0800 | tok/s 48593 | tokens 378,470,400 | time 7785.55s
# step 46300 | train loss 3.9742 | val loss 4.0222 | tok/s 48667 | tokens 379,289,600 | time 7802.38s
# step 46400 | train loss 3.9995 | val loss 4.0691 | tok/s 48615 | tokens 380,108,800 | time 7819.23s
# step 46500 | train loss 3.9936 | val loss 4.0410 | tok/s 48621 | tokens 380,928,000 | time 7836.08s
# step 46600 | train loss 4.0039 | val loss 4.0660 | tok/s 48585 | tokens 381,747,200 | time 7852.94s
# step 46700 | train loss 4.0018 | val loss 4.0055 | tok/s 48735 | tokens 382,566,400 | time 7869.75s
# step 46800 | train loss 4.0138 | val loss 4.0799 | tok/s 48747 | tokens 383,385,600 | time 7886.55s
# step 46900 | train loss 4.0292 | val loss 4.0336 | tok/s 48550 | tokens 384,204,800 | time 7903.43s
# step 47000 | train loss 3.9826 | val loss 4.0769 | tok/s 48529 | tokens 385,024,000 | time 7920.31s
# step 47100 | train loss 4.0124 | val loss 3.9951 | tok/s 48607 | tokens 385,843,200 | time 7937.16s
# step 47200 | train loss 3.9815 | val loss 3.9842 | tok/s 48616 | tokens 386,662,400 | time 7954.01s
# step 47300 | train loss 3.9999 | val loss 4.0195 | tok/s 48631 | tokens 387,481,600 | time 7970.86s
# step 47400 | train loss 3.9709 | val loss 4.0362 | tok/s 48433 | tokens 388,300,800 | time 7987.77s
# step 47500 | train loss 3.9891 | val loss 4.0468 | tok/s 48652 | tokens 389,120,000 | time 8004.61s
# step 47600 | train loss 3.9894 | val loss 4.0414 | tok/s 48633 | tokens 389,939,200 | time 8021.45s
# step 47700 | train loss 3.9756 | val loss 4.0789 | tok/s 48720 | tokens 390,758,400 | time 8038.27s
# step 47800 | train loss 4.0000 | val loss 4.0346 | tok/s 48638 | tokens 391,577,600 | time 8055.11s
# step 47900 | train loss 3.9570 | val loss 4.0165 | tok/s 48694 | tokens 392,396,800 | time 8071.93s
# step 48000 | train loss 4.0022 | val loss 3.9932 | tok/s 48638 | tokens 393,216,000 | time 8088.77s
# ...
# step 84300 | train loss 3.9111 | val loss 3.9419 | tok/s 48640 | tokens 690,585,600 | time 14209.13s
# step 84400 | train loss 3.8311 | val loss 3.9095 | tok/s 48488 | tokens 691,404,800 | time 14226.03s
# step 84500 | train loss 3.8888 | val loss 3.8915 | tok/s 48712 | tokens 692,224,000 | time 14242.84s
# step 84600 | train loss 3.8164 | val loss 3.9436 | tok/s 48519 | tokens 693,043,200 | time 14259.73s
# step 84700 | train loss 3.8494 | val loss 3.9599 | tok/s 48519 | tokens 693,862,400 | time 14276.61s
# step 84800 | train loss 3.8968 | val loss 3.9412 | tok/s 48473 | tokens 694,681,600 | time 14293.51s
# step 84900 | train loss 3.8993 | val loss 3.9310 | tok/s 48541 | tokens 695,500,800 | time 14310.39s
# step 85000 | train loss 3.8870 | val loss 3.8783 | tok/s 48561 | tokens 696,320,000 | time 14327.26s
# step 85100 | train loss 3.8665 | val loss 3.8939 | tok/s 48611 | tokens 697,139,200 | time 14344.11s
# step 85200 | train loss 3.8395 | val loss 3.9603 | tok/s 48624 | tokens 697,958,400 | time 14360.96s
# step 85300 | train loss 3.8494 | val loss 3.9128 | tok/s 48603 | tokens 698,777,600 | time 14377.81s
# step 85400 | train loss 3.8672 | val loss 3.8917 | tok/s 48648 | tokens 699,596,800 | time 14394.65s
# step 85500 | train loss 3.8811 | val loss 3.8747 | tok/s 48668 | tokens 700,416,000 | time 14411.48s
# step 85600 | train loss 3.8309 | val loss 3.9211 | tok/s 48491 | tokens 701,235,200 | time 14428.38s
# step 85700 | train loss 3.8741 | val loss 3.9081 | tok/s 48418 | tokens 702,054,400 | time 14445.30s
# step 85800 | train loss 3.8821 | val loss 3.9469 | tok/s 48549 | tokens 702,873,600 | time 14462.17s
# step 85900 | train loss 3.8675 | val loss 3.9848 | tok/s 48615 | tokens 703,692,800 | time 14479.02s
# step 86000 | train loss 3.8590 | val loss 3.9113 | tok/s 48660 | tokens 704,512,000 | time 14495.85s
# step 86100 | train loss 3.8662 | val loss 3.9131 | tok/s 48593 | tokens 705,331,200 | time 14512.71s
# step 86200 | train loss 3.8294 | val loss 3.9386 | tok/s 48553 | tokens 706,150,400 | time 14529.59s
# step 86300 | train loss 3.8606 | val loss 3.9623 | tok/s 48711 | tokens 706,969,600 | time 14546.40s
# step 86400 | train loss 3.9028 | val loss 3.9866 | tok/s 48640 | tokens 707,788,800 | time 14563.24s
# step 86500 | train loss 3.8592 | val loss 3.9309 | tok/s 48619 | tokens 708,608,000 | time 14580.09s
# step 86600 | train loss 3.7976 | val loss 3.9153 | tok/s 48532 | tokens 709,427,200 | time 14596.97s
# step 86700 | train loss 3.8005 | val loss 3.9301 | tok/s 48601 | tokens 710,246,400 | time 14613.83s
# step 86800 | train loss 3.8460 | val loss 3.9155 | tok/s 48593 | tokens 711,065,600 | time 14630.69s
# step 86900 | train loss 3.8922 | val loss 3.9017 | tok/s 48530 | tokens 711,884,800 | time 14647.57s
# step 87000 | train loss 3.8687 | val loss 3.8771 | tok/s 48539 | tokens 712,704,000 | time 14664.44s
# step 87100 | train loss 3.8262 | val loss 3.9442 | tok/s 48688 | tokens 713,523,200 | time 14681.27s
# step 87200 | train loss 3.9056 | val loss 3.9138 | tok/s 48611 | tokens 714,342,400 | time 14698.12s
# step 87300 | train loss 3.8521 | val loss 3.9659 | tok/s 48425 | tokens 715,161,600 | time 14715.04s
# step 87400 | train loss 3.8171 | val loss 3.9344 | tok/s 48529 | tokens 715,980,800 | time 14731.92s
# step 87500 | train loss 3.8992 | val loss 3.9356 | tok/s 48610 | tokens 716,800,000 | time 14748.77s
# step 87600 | train loss 3.9117 | val loss 3.9958 | tok/s 48582 | tokens 717,619,200 | time 14765.63s
# step 87700 | train loss 3.8579 | val loss 3.9390 | tok/s 48507 | tokens 718,438,400 | time 14782.52s
# step 87800 | train loss 3.9537 | val loss 3.9129 | tok/s 48506 | tokens 719,257,600 | time 14799.41s
# step 87900 | train loss 3.8428 | val loss 3.9278 | tok/s 48454 | tokens 720,076,800 | time 14816.32s
# step 88000 | train loss 3.8150 | val loss 3.9358 | tok/s 48430 | tokens 720,896,000 | time 14833.23s
# step 88100 | train loss 3.8506 | val loss 3.9639 | tok/s 48476 | tokens 721,715,200 | time 14850.13s
# step 88200 | train loss 3.8580 | val loss 3.9429 | tok/s 48451 | tokens 722,534,400 | time 14867.04s
# step 88300 | train loss 3.8488 | val loss 3.9501 | tok/s 48528 | tokens 723,353,600 | time 14883.92s
# step 88400 | train loss 3.9306 | val loss 3.9391 | tok/s 48671 | tokens 724,172,800 | time 14900.75s
# step 88500 | train loss 3.8122 | val loss 3.8918 | tok/s 48583 | tokens 724,992,000 | time 14917.61s
# step 88600 | train loss 3.8451 | val loss 3.9094 | tok/s 48539 | tokens 725,811,200 | time 14934.49s
# step 88700 | train loss 3.9275 | val loss 3.9315 | tok/s 48450 | tokens 726,630,400 | time 14951.40s
# step 88800 | train loss 3.8268 | val loss 3.9183 | tok/s 48560 | tokens 727,449,600 | time 14968.27s
# step 88900 | train loss 3.7968 | val loss 3.8880 | tok/s 48627 | tokens 728,268,800 | time 14985.11s
# step 89000 | train loss 3.8812 | val loss 3.9627 | tok/s 48528 | tokens 729,088,000 | time 15001.99s
# step 89100 | train loss 3.8505 | val loss 3.9260 | tok/s 48561 | tokens 729,907,200 | time 15018.86s
# step 89200 | train loss 3.8541 | val loss 3.9066 | tok/s 48577 | tokens 730,726,400 | time 15035.73s
# step 89300 | train loss 3.8573 | val loss 3.8208 | tok/s 48620 | tokens 731,545,600 | time 15052.57s
# step 89400 | train loss 3.9488 | val loss 3.9246 | tok/s 48697 | tokens 732,364,800 | time 15069.40s
# step 89500 | train loss 3.8590 | val loss 3.8562 | tok/s 48531 | tokens 733,184,000 | time 15086.28s
# step 89600 | train loss 3.8430 | val loss 3.9106 | tok/s 48373 | tokens 734,003,200 | time 15103.21s
# step 89700 | train loss 3.8452 | val loss 3.9110 | tok/s 48365 | tokens 734,822,400 | time 15120.15s
# step 89800 | train loss 3.8926 | val loss 3.9008 | tok/s 48408 | tokens 735,641,600 | time 15137.07s
# step 89900 | train loss 3.8224 | val loss 3.8679 | tok/s 48197 | tokens 736,460,800 | time 15154.07s
# step 90000 | train loss 3.8677 | val loss 3.9395 | tok/s 48273 | tokens 737,280,000 | time 15171.04s
# step 90100 | train loss 3.9262 | val loss 3.9144 | tok/s 48450 | tokens 738,099,200 | time 15187.95s
# step 90200 | train loss 3.8596 | val loss 3.9499 | tok/s 48337 | tokens 738,918,400 | time 15204.89s
# step 90300 | train loss 3.7905 | val loss 3.9095 | tok/s 48477 | tokens 739,737,600 | time 15221.79s
# step 90400 | train loss 3.8357 | val loss 3.8902 | tok/s 48356 | tokens 740,556,800 | time 15238.73s
# step 90500 | train loss 3.9097 | val loss 3.9182 | tok/s 48260 | tokens 741,376,000 | time 15255.71s
# step 90600 | train loss 3.8733 | val loss 3.8991 | tok/s 48428 | tokens 742,195,200 | time 15272.62s
# step 90700 | train loss 3.8167 | val loss 3.9391 | tok/s 48277 | tokens 743,014,400 | time 15289.59s
# step 90800 | train loss 3.8223 | val loss 3.9752 | tok/s 48447 | tokens 743,833,600 | time 15306.50s
# step 90900 | train loss 3.8432 | val loss 3.9418 | tok/s 48478 | tokens 744,652,800 | time 15323.40s
# step 91000 | train loss 3.7953 | val loss 3.9465 | tok/s 48391 | tokens 745,472,000 | time 15340.33s
# step 91100 | train loss 3.8567 | val loss 3.8883 | tok/s 48418 | tokens 746,291,200 | time 15357.25s
# step 91200 | train loss 3.8267 | val loss 3.9413 | tok/s 48346 | tokens 747,110,400 | time 15374.19s
# step 91300 | train loss 3.8379 | val loss 3.8996 | tok/s 48374 | tokens 747,929,600 | time 15391.13s
# step 91400 | train loss 3.8824 | val loss 3.9338 | tok/s 48466 | tokens 748,748,800 | time 15408.03s
# step 91500 | train loss 3.9066 | val loss 3.8897 | tok/s 48512 | tokens 749,568,000 | time 15424.92s
# step 91600 | train loss 3.8818 | val loss 3.9404 | tok/s 48510 | tokens 750,387,200 | time 15441.80s
# step 91700 | train loss 3.8433 | val loss 3.9212 | tok/s 48533 | tokens 751,206,400 | time 15458.68s
# step 91800 | train loss 3.8391 | val loss 3.8868 | tok/s 48522 | tokens 752,025,600 | time 15475.56s
# step 91900 | train loss 3.8929 | val loss 3.8903 | tok/s 48463 | tokens 752,844,800 | time 15492.47s
# step 92000 | train loss 3.8841 | val loss 3.9018 | tok/s 48382 | tokens 753,664,000 | time 15509.40s
# step 92100 | train loss 3.8150 | val loss 3.9080 | tok/s 48369 | tokens 754,483,200 | time 15526.34s
# step 92200 | train loss 3.7731 | val loss 3.9037 | tok/s 48479 | tokens 755,302,400 | time 15543.23s
# step 92300 | train loss 3.8715 | val loss 3.8949 | tok/s 48373 | tokens 756,121,600 | time 15560.17s
# step 92400 | train loss 3.7794 | val loss 3.8833 | tok/s 48414 | tokens 756,940,800 | time 15577.09s
# step 92500 | train loss 3.7905 | val loss 3.8328 | tok/s 48303 | tokens 757,760,000 | time 15594.05s
# step 92600 | train loss 3.8462 | val loss 3.8861 | tok/s 48435 | tokens 758,579,200 | time 15610.96s
# step 92700 | train loss 3.8574 | val loss 3.8713 | tok/s 48383 | tokens 759,398,400 | time 15627.89s
# step 92800 | train loss 3.8461 | val loss 3.8461 | tok/s 48470 | tokens 760,217,600 | time 15644.79s
# step 92900 | train loss 3.8433 | val loss 3.9371 | tok/s 48487 | tokens 761,036,800 | time 15661.69s
# step 93000 | train loss 3.8636 | val loss 3.8628 | tok/s 48338 | tokens 761,856,000 | time 15678.64s
# step 93100 | train loss 3.8588 | val loss 3.9388 | tok/s 48339 | tokens 762,675,200 | time 15695.58s
# step 93200 | train loss 3.8867 | val loss 3.8989 | tok/s 48444 | tokens 763,494,400 | time 15712.49s
# step 93300 | train loss 3.8499 | val loss 3.9063 | tok/s 48479 | tokens 764,313,600 | time 15729.39s
# step 93400 | train loss 3.8222 | val loss 3.8901 | tok/s 48402 | tokens 765,132,800 | time 15746.32s
# step 93500 | train loss 3.8471 | val loss 3.9429 | tok/s 48444 | tokens 765,952,000 | time 15763.23s
# step 93600 | train loss 3.8597 | val loss 3.9177 | tok/s 48447 | tokens 766,771,200 | time 15780.14s
# step 93700 | train loss 3.8118 | val loss 3.9176 | tok/s 48483 | tokens 767,590,400 | time 15797.03s
# step 93800 | train loss 3.8311 | val loss 3.9361 | tok/s 48469 | tokens 768,409,600 | time 15813.93s
# step 93900 | train loss 3.8703 | val loss 3.9165 | tok/s 48454 | tokens 769,228,800 | time 15830.84s
# step 94000 | train loss 3.8457 | val loss 3.9078 | tok/s 48440 | tokens 770,048,000 | time 15847.75s
# step 94100 | train loss 3.8093 | val loss 3.8912 | tok/s 48468 | tokens 770,867,200 | time 15864.65s
# step 94200 | train loss 3.9424 | val loss 3.9065 | tok/s 48344 | tokens 771,686,400 | time 15881.60s
# step 94300 | train loss 3.8971 | val loss 3.9026 | tok/s 48527 | tokens 772,505,600 | time 15898.48s
# step 94400 | train loss 3.9013 | val loss 3.8695 | tok/s 48478 | tokens 773,324,800 | time 15915.38s
# step 94500 | train loss 3.8639 | val loss 3.9109 | tok/s 48387 | tokens 774,144,000 | time 15932.31s
# step 94600 | train loss 3.8795 | val loss 3.9809 | tok/s 48564 | tokens 774,963,200 | time 15949.18s
# step 94700 | train loss 3.9030 | val loss 3.9298 | tok/s 48366 | tokens 775,782,400 | time 15966.11s
# step 94800 | train loss 3.8365 | val loss 3.8490 | tok/s 48449 | tokens 776,601,600 | time 15983.02s
# step 94900 | train loss 3.8817 | val loss 3.9900 | tok/s 48396 | tokens 777,420,800 | time 15999.95s
# step 95000 | train loss 3.8342 | val loss 3.9556 | tok/s 48483 | tokens 778,240,000 | time 16016.84s
# step 95100 | train loss 3.8855 | val loss 3.8801 | tok/s 48603 | tokens 779,059,200 | time 16033.70s
# step 95200 | train loss 3.8415 | val loss 3.9062 | tok/s 48420 | tokens 779,878,400 | time 16050.62s
# step 95300 | train loss 3.8339 | val loss 3.9263 | tok/s 48368 | tokens 780,697,600 | time 16067.55s
# step 95400 | train loss 3.8010 | val loss 3.9326 | tok/s 48471 | tokens 781,516,800 | time 16084.46s
# step 95500 | train loss 3.7542 | val loss 3.9046 | tok/s 48528 | tokens 782,336,000 | time 16101.34s
# step 95600 | train loss 3.8613 | val loss 3.8949 | tok/s 48507 | tokens 783,155,200 | time 16118.22s
# step 95700 | train loss 3.8185 | val loss 3.9257 | tok/s 48474 | tokens 783,974,400 | time 16135.12s
# step 95800 | train loss 3.8640 | val loss 3.9425 | tok/s 48393 | tokens 784,793,600 | time 16152.05s
# step 95900 | train loss 3.8216 | val loss 3.9233 | tok/s 48415 | tokens 785,612,800 | time 16168.97s
# step 96000 | train loss 3.8946 | val loss 3.9179 | tok/s 48391 | tokens 786,432,000 | time 16185.90s
# step 96100 | train loss 3.8487 | val loss 3.8771 | tok/s 48324 | tokens 787,251,200 | time 16202.85s
# step 96200 | train loss 3.8198 | val loss 3.8812 | tok/s 48501 | tokens 788,070,400 | time 16219.74s
# step 96300 | train loss 3.8506 | val loss 3.8722 | tok/s 48221 | tokens 788,889,600 | time 16236.73s
# step 96400 | train loss 3.8059 | val loss 3.9071 | tok/s 48376 | tokens 789,708,800 | time 16253.66s
# step 96500 | train loss 3.8781 | val loss 3.8925 | tok/s 48188 | tokens 790,528,000 | time 16270.66s
# step 96600 | train loss 3.8438 | val loss 3.8725 | tok/s 48456 | tokens 791,347,200 | time 16287.57s
# step 96700 | train loss 3.8134 | val loss 3.9248 | tok/s 48338 | tokens 792,166,400 | time 16304.52s
# step 96800 | train loss 3.7999 | val loss 3.9217 | tok/s 48415 | tokens 792,985,600 | time 16321.44s
# step 96900 | train loss 3.8142 | val loss 3.9120 | tok/s 48359 | tokens 793,804,800 | time 16338.38s
# step 97000 | train loss 3.8357 | val loss 3.9370 | tok/s 48361 | tokens 794,624,000 | time 16355.32s
# step 97100 | train loss 3.8570 | val loss 3.8696 | tok/s 48395 | tokens 795,443,200 | time 16372.24s
# step 97200 | train loss 3.8171 | val loss 3.9183 | tok/s 48466 | tokens 796,262,400 | time 16389.15s
# step 97300 | train loss 3.8527 | val loss 3.8891 | tok/s 48335 | tokens 797,081,600 | time 16406.10s
# step 97400 | train loss 3.8752 | val loss 3.9314 | tok/s 48315 | tokens 797,900,800 | time 16423.05s
# step 97500 | train loss 3.8433 | val loss 3.8599 | tok/s 48313 | tokens 798,720,000 | time 16440.01s
# step 97600 | train loss 3.8586 | val loss 3.9350 | tok/s 48396 | tokens 799,539,200 | time 16456.93s
# step 97700 | train loss 3.8339 | val loss 3.9029 | tok/s 48526 | tokens 800,358,400 | time 16473.81s
# step 97800 | train loss 3.8272 | val loss 3.9309 | tok/s 48353 | tokens 801,177,600 | time 16490.76s
# step 97900 | train loss 3.9024 | val loss 3.8697 | tok/s 48381 | tokens 801,996,800 | time 16507.69s
# step 98000 | train loss 3.8356 | val loss 3.8919 | tok/s 48479 | tokens 802,816,000 | time 16524.59s
# step 98100 | train loss 3.8377 | val loss 3.8587 | tok/s 48359 | tokens 803,635,200 | time 16541.53s
# step 98200 | train loss 3.7501 | val loss 3.9030 | tok/s 48323 | tokens 804,454,400 | time 16558.48s
# step 98300 | train loss 3.7914 | val loss 3.9287 | tok/s 48198 | tokens 805,273,600 | time 16575.47s
# step 98400 | train loss 3.8051 | val loss 3.8826 | tok/s 48395 | tokens 806,092,800 | time 16592.40s
# step 98500 | train loss 3.8357 | val loss 3.8813 | tok/s 48504 | tokens 806,912,000 | time 16609.29s
# step 98600 | train loss 3.8907 | val loss 3.9279 | tok/s 48270 | tokens 807,731,200 | time 16626.26s
# step 98700 | train loss 3.8189 | val loss 3.9837 | tok/s 48536 | tokens 808,550,400 | time 16643.14s
# step 98800 | train loss 3.8335 | val loss 3.8271 | tok/s 48443 | tokens 809,369,600 | time 16660.05s
# step 98900 | train loss 3.8109 | val loss 3.9134 | tok/s 48486 | tokens 810,188,800 | time 16676.95s
# step 99000 | train loss 3.8406 | val loss 3.9199 | tok/s 48475 | tokens 811,008,000 | time 16693.85s
# step 99100 | train loss 3.7870 | val loss 3.8625 | tok/s 48410 | tokens 811,827,200 | time 16710.77s
# step 99200 | train loss 3.8495 | val loss 3.9218 | tok/s 48551 | tokens 812,646,400 | time 16727.64s
# step 99300 | train loss 3.8239 | val loss 3.8434 | tok/s 48490 | tokens 813,465,600 | time 16744.53s
# step 99400 | train loss 3.8033 | val loss 3.8600 | tok/s 48460 | tokens 814,284,800 | time 16761.44s
# step 99500 | train loss 3.8025 | val loss 3.8901 | tok/s 48365 | tokens 815,104,000 | time 16778.38s
# step 99600 | train loss 3.8672 | val loss 3.9457 | tok/s 48425 | tokens 815,923,200 | time 16795.29s
# step 99700 | train loss 3.8702 | val loss 3.8782 | tok/s 48485 | tokens 816,742,400 | time 16812.19s
# step 99800 | train loss 3.8137 | val loss 3.9472 | tok/s 48502 | tokens 817,561,600 | time 16829.08s
# step 99900 | train loss 3.8683 | val loss 3.8365 | tok/s 48499 | tokens 818,380,800 | time 16845.97s
# step 100000 | train loss 3.8388 | val loss 3.9241 | tok/s 48420 | tokens 819,200,000 | time 16862.89s

# %% [markdown]
# 横軸を`Step`、縦軸を`Loss`として`matplotlib`を使って描画しましょう。

# %%
# グラフ描画。
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 5))
plt.plot(trainer.steps, trainer.train_losses, label='Train Loss')
plt.plot(trainer.steps, trainer.val_losses, label='Validation Loss')
plt.xlabel('Step')
plt.ylabel('Loss')
plt.title('Training and Validation Loss over Steps')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# おそらく、文字ごとにやった時よりもロスの下がり方が鈍くなっているはずです。
#
# ぜひ、結果を自分なりに考察してください。

# %%
# 推論もやってみる
# 評価モードに切り替え。ドロップアウトを無効化する。
model.eval()
print("Model set to eval mode")
# Out:
# Model set to eval mode

# %%
prompt = "New York is"
print(f"\n入力プロンプト: {prompt}")

# トークナイズしてテンソル化
encoded = data_loader.encode(prompt) # テキストをIDにエンコード
print("encoded", encoded)
encoded_tensor = torch.tensor(encoded, dtype=torch.long) # IDのリストをテンソルの形式に変換する
print_formatted_tensor(encoded_tensor)
encoded_tensor = encoded_tensor.unsqueeze(0)  # バッチ次元追加
print_formatted_tensor(encoded_tensor)
encoded_tensor = encoded_tensor.to(config.device_type) # cuda(GPU)にencoded_tensorを転送する
print_formatted_tensor(encoded_tensor)
# Out:
# 入力プロンプト: New York is
# encoded [3791, 1971, 318]
# Tensor Size: [3]
# tensor([
#          3791.00, 1971.00, 318.00
#        ])
# Tensor Size: [1, 3]
# tensor([
#          [3791.00, 1971.00, 318.00]
#        ])
# Tensor Size: [1, 3]
# tensor([
#          [3791.00, 1971.00, 318.00]
#        ])

# %%
# テキスト生成
generated_text = model.generate(encoded_tensor, max_new_tokens=512)

# %%
decoded_text = data_loader.decode(generated_text[0].tolist())
print(decoded_text)
# Out:
# New York is the most important example of US imperialism affecting the fledgling Americas.
# Many countries suffer military disasters. Since they have been effectively creeping and threatening worsening situations, policies, and relying on prayer in the context of the moment, discussions about the cause of war have been not always difficult.
# Setting the capabilities of coercive tactics may seem at the beginning too small in the Warsaw Pact. The implications of biggest militarisation of the USSR sat on the issue of war on regional instability does not hold a lot of time.
# The advice of the Caucasus is that Russia has no intention of blocking terrorism out of its core. Russia also has many steps to follow if even its invasion strategy.
# It is the history of the Kedene Party. The Romanian cristy Russia was the only political party to stand in the battle. During the 18th century, Byzantal Charles left his family behind and left his family suddenly to propose a new supporters saying they would have shared it with Britain. Today the image of the Kedene Party is made by Czechoslovak shamans. The salvation of Bulgaria the Tsaú i was the half-braid of the Bulgarians throughout the 19th century as remembered by fan Andre Lóröff. However, Gorgenus was mother to teenager Katshenitsia and suck her hand down and gave birth to a bright generation. Throughout the 17th century, this book was never published without the letter of Franz Boz), Dadat is still the smallest. Zakaro will be sent away to the northern Sudan from his daughter's grave in November 1839 to present with the Russian king and his companion-in-law. It would appear that the women in the rivers could only speak to the hated Karolgia when summoned. Finally, the Russian war in former Yugoslavia and in 2007, the Russian army declared that West Germany abdicate the presence of Emir Lóröff. On the other hand, the Russian army supported a Timaeus exile Hitler from the location of Datrey to Bogang (Hittin of the Russian Empire).
# The next phase is to attack their homeland on Riemannaga, along with other members of the Kedene Party and collect Russian oil giant Athaby and Queen Matzanski and the Hittin of Scholestach, which is home to massive expanse of nation. The Ukraine ceases to state by becoming a salt marsh within its waters. The ESA considers the Hittin a total of 173,400 Armenian francs, 3 percent of the

# %% [markdown]
# New York is the most important example of US imperialism affecting the fledgling Americas.
# Many countries suffer military disasters. Since they have been effectively creeping and threatening worsening situations, policies, and relying on prayer in the context of the moment, discussions about the cause of war have been not always difficult.
# Setting the capabilities of coercive tactics may seem at the beginning too small in the Warsaw Pact. The implications of biggest militarisation of the USSR sat on the issue of war on regional instability does not hold a lot of time.
# The advice of the Caucasus is that Russia has no intention of blocking terrorism out of its core. Russia also has many steps to follow if even its invasion strategy.
# It is the history of the Kedene Party. The Romanian cristy Russia was the only political party to stand in the battle. During the 18th century, Byzantal Charles left his family behind and left his family suddenly to propose a new supporters saying they would have shared it with Britain. Today the image of the Kedene Party is made by Czechoslovak shamans. The salvation of Bulgaria the Tsaú i was the half-braid of the Bulgarians throughout the 19th century as remembered by fan Andre Lóröff. However, Gorgenus was mother to teenager Katshenitsia and suck her hand down and gave birth to a bright generation. Throughout the 17th century, this book was never published without the letter of Franz Boz), Dadat is still the smallest. Zakaro will be sent away to the northern Sudan from his daughter's grave in November 1839 to present with the Russian king and his companion-in-law. It would appear that the women in the rivers could only speak to the hated Karolgia when summoned. Finally, the Russian war in former Yugoslavia and in 2007, the Russian army declared that West Germany abdicate the presence of Emir Lóröff. On the other hand, the Russian army supported a Timaeus exile Hitler from the location of Datrey to Bogang (Hittin of the Russian Empire).
# The next phase is to attack their homeland on Riemannaga, along with other members of the Kedene Party and collect Russian oil giant Athaby and Queen Matzanski and the Hittin of Scholestach, which is home to massive expanse of nation. The Ukraine ceases to state by becoming a salt marsh within its waters. The ESA considers the Hittin a total of 173,400 Armenian francs, 3 percent of the

# %% [markdown]
# 今回もT4 GPUをたっぷり使って学習してるので、学習ログはきちんと保管しましょう。
#
# おすすめはGoole Driveです。

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 学習済み trainer からログをまとめる
results = {
    "step": trainer.steps,
    "train_loss": trainer.train_losses,
    "val_loss": trainer.val_losses,
    "total_seen_tokens": trainer.total_seen_tokens_list,
    "total_train_time": trainer.total_train_time_list,
}

print(results)
# Out:
# {'step': [0, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300, 2400, 2500, 2600, 2700, 2800, 2900, 3000, 3100, 3200, 3300, 3400, 3500, 3600, 3700, 3800, 3900, 4000, 4100, 4200, 4300, 4400, 4500, 4600, 4700, 4800, 4900, 5000, 5100, 5200, 5300, 5400, 5500, 5600, 5700, 5800, 5900, 6000, 6100, 6200, 6300, 6400, 6500, 6600, 6700, 6800, 6900, 7000, 7100, 7200, 7300, 7400, 7500, 7600, 7700, 7800, 7900, 8000, 8100, 8200, 8300, 8400, 8500, 8600, 8700, 8800, 8900, 9000, 9100, 9200, 9300, 9400, 9500, 9600, 9700, 9800, 9900, 10000, 10100, 10200, 10300, 10400, 10500, 10600, 10700, 10800, 10900, 11000, 11100, 11200, 11300, 11400, 11500, 11600, 11700, 11800, 11900, 12000, 12100, 12200, 12300, 12400, 12500, 12600, 12700, 12800, 12900, 13000, 13100, 13200, 13300, 13400, 13500, 13600, 13700, 13800, 13900, 14000, 14100, 14200, 14300, 14400, 14500, 14600, 14700, 14800, 14900, 15000, 15100, 15200, 15300, 15400, 15500, 15600, 15700, 15800, 15900, 16000, 16100, 16200, 16300, 16400, 16500, 16600, 16700, 16800, 16900, 17000, 17100, 17200, 17300, 17400, 17500, 17600, 17700, 17800, 17900, 18000, 18100, 18200, 18300, 18400, 18500, 18600, 18700, 18800, 18900, 19000, 19100, 19200, 19300, 19400, 19500, 19600, 19700, 19800, 19900, 20000, 20100, 20200, 20300, 20400, 20500, 20600, 20700, 20800, 20900, 21000, 21100, 21200, 21300, 21400, 21500, 21600, 21700, 21800, 21900, 22000, 22100, 22200, 22300, 22400, 22500, 22600, 22700, 22800, 22900, 23000, 23100, 23200, 23300, 23400, 23500, 23600, 23700, 23800, 23900, 24000, 24100, 24200, 24300, 24400, 24500, 24600, 24700, 24800, 24900, 25000, 25100, 25200, 25300, 25400, 25500, 25600, 25700, 25800, 25900, 26000, 26100, 26200, 26300, 26400, 26500, 26600, 26700, 26800, 26900, 27000, 27100, 27200, 27300, 27400, 27500, 27600, 27700, 27800, 27900, 28000, 28100, 28200, 28300, 28400, 28500, 28600, 28700, 28800, 28900, 29000, 29100, 29200, 29300, 29400, 29500, 29600, 29700, 29800, 29900, 30000, 30100, 30200, 30300, 30400, 30500, 30600, 30700, 30800, 30900, 31000, 31100, 31200, 31300, 31400, 31500, 31600, 31700, 31800, 31900, 32000, 32100, 32200, 32300, 32400, 32500, 32600, 32700, 32800, 32900, 33000, 33100, 33200, 33300, 33400, 33500, 33600, 33700, 33800, 33900, 34000, 34100, 34200, 34300, 34400, 34500, 34600, 34700, 34800, 34900, 35000, 35100, 35200, 35300, 35400, 35500, 35600, 35700, 35800, 35900, 36000, 36100, 36200, 36300, 36400, 36500, 36600, 36700, 36800, 36900, 37000, 37100, 37200, 37300, 37400, 37500, 37600, 37700, 37800, 37900, 38000, 38100, 38200, 38300, 38400, 38500, 38600, 38700, 38800, 38900, 39000, 39100, 39200, 39300, 39400, 39500, 39600, 39700, 39800, 39900, 40000, 40100, 40200, 40300, 40400, 40500, 40600, 40700, 40800, 40900, 41000, 41100, 41200, 41300, 41400, 41500, 41600, 41700, 41800, 41900, 42000, 42100, 42200, 42300, 42400, 42500, 42600, 42700, 42800, 42900, 43000, 43100, 43200, 43300, 43400, 43500, 43600, 43700, 43800, 43900, 44000, 44100, 44200, 44300, 44400, 44500, 44600, 44700, 44800, 44900, 45000, 45100, 45200, 45300, 45400, 45500, 45600, 45700, 45800, 45900, 46000, 46100, 46200, 46300, 46400, 46500, 46600, 46700, 46800, 46900, 47000, 47100, 47200, 47300, 47400, 47500, 47600, 47700, 47800, 47900, 48000, 48100, 48200, 48300, 48400, 48500, 48600, 48700, 48800, 48900, 49000, 49100, 49200, 49300, 49400, 49500, 49600, 49700, 49800, 49900, 50000, 50100, 50200, 50300, 50400, 50500, 50600, 50700, 50800, 50900, 51000, 51100, 51200, 51300, 51400, 51500, 51600, 51700, 51800, 51900, 52000, 52100, 52200, 52300, 52400, 52500, 52600, 52700, 52800, 52900, 53000, 53100, 53200, 53300, 53400, 53500, 53600, 53700, 53800, 53900, 54000, 54100, 54200, 54300, 54400, 54500, 54600, 54700, 54800, 54900, 55000, 55100, 55200, 55300, 55400, 55500, 55600, 55700, 55800, 55900, 56000, 56100, 56200, 56300, 56400, 56500, 56600, 56700, 56800, 56900, 57000, 57100, 57200, 57300, 57400, 57500, 57600, 57700, 57800, 57900, 58000, 58100, 58200, 58300, 58400, 58500,  ...

# %%
import pandas as pd
# pandas の DataFrame に変換
df = pd.DataFrame(results)

# %%
df
# Out:
#         step  train_loss   val_loss  total_seen_tokens  total_train_time
# 0          0   10.998332  10.993977                  0          0.000000
# 1        100    7.121319   7.128767             819200         17.168127
# 2        200    6.826391   6.796621            1638400         34.022541
# 3        300    6.618788   6.627958            2457600         50.826560
# 4        400    6.437109   6.457681            3276800         67.687531
# ...      ...         ...        ...                ...               ...
# 996    99600    3.867248   3.945741          815923200      16795.293288
# 997    99700    3.870187   3.878230          816742400      16812.189194
# 998    99800    3.813741   3.947154          817561600      16829.079080
# 999    99900    3.868260   3.836536          818380800      16845.969818
# 1000  100000    3.838841   3.924066          819200000      16862.888270
#
# [1001 rows x 5 columns]

# %%
# 保存先のフォルダを作成する
import os
dir_path = "/content/drive/MyDrive/nanoGPT_logs/Chapter18"
os.makedirs(dir_path, exist_ok=True)

# %%
# csvファイルとして保存する先のパスを指定する。
save_path = "/content/drive/MyDrive/nanoGPT_logs/Chapter18/training_logs.csv"

# %%
# CSVとして保存
df.to_csv(save_path, index=False)
print(f"✅ CSV saved to: {save_path}")
# Out:
# ✅ CSV saved to: /content/drive/MyDrive/nanoGPT_logs/Chapter18/training_logs.csv

# %%
# クラス属性を辞書化
config_class_dict = vars(config.__class__)
print(config_class_dict)
# Out:
# {'__module__': '__main__', 'batch_size': 16, 'input_sequence_length': 512, 'total_training_steps': 100000, 'device_type': 'cuda', 'evaluation_frequency': 100, 'learning_rate': 0.001, 'evaluation_loops': 10, 'embedding_dim': 512, 'hidden_dim': 2048, 'num_attention_heads': 8, 'layer_count': 4, 'dropout_rate': 0.1, 'random_seed_value': 1337, '__dict__': <attribute '__dict__' of 'ModelConfig' objects>, '__weakref__': <attribute '__weakref__' of 'ModelConfig' objects>, '__doc__': None}

# %%
# 辞書の (key, value) ペアを取得
config_dict_items = config_class_dict.items()
print(config_dict_items)
# Out:
# dict_items([('__module__', '__main__'), ('batch_size', 16), ('input_sequence_length', 512), ('total_training_steps', 100000), ('device_type', 'cuda'), ('evaluation_frequency', 100), ('learning_rate', 0.001), ('evaluation_loops', 10), ('embedding_dim', 512), ('hidden_dim', 2048), ('num_attention_heads', 8), ('layer_count', 4), ('dropout_rate', 0.1), ('random_seed_value', 1337), ('__dict__', <attribute '__dict__' of 'ModelConfig' objects>), ('__weakref__', <attribute '__weakref__' of 'ModelConfig' objects>), ('__doc__', None)])

# %%
config_dict = {
    key: value
    for key, value in config_dict_items
    if not key.startswith("__")
}

print(config_dict)

# %%
# 保存先のファイルパスを作成する。
# dir_path = "/content/drive/MyDrive/nanoGPT_logs/Chapter17"
config_path = os.path.join(dir_path, "model_config.json")
print(config_path)

# %%
import json
# ファイルを「書き込みモード(w)」で開き、変数`f`で操作できるようにする
with open(config_path, "w") as f:
    json.dump(config_dict, f)

print(f"✅ Config saved to: {config_path}")

# %%
model_path = os.path.join(dir_path, "model_weights.pt")
print(model_path)
# Out:
# /content/drive/MyDrive/nanoGPT_logs/Chapter18/model_weights.pt

# %%
torch.save(model.state_dict(), model_path)
print(f"Model saved to {model_path}")
# Out:
# Model saved to /content/drive/MyDrive/nanoGPT_logs/Chapter18/model_weights.pt

# %% [markdown]
# **Section 3: tiktokenで学習** <label><input type="checkbox"> Mark as Done</label>

# %% [markdown]
# **⚠️ 右上の 🔽 からランタイムを接続解除してクレジット消費を止めてください。** <label><input type="checkbox">接続解除した</label>

# %% [markdown]
# **Chapter 18: tiktoken** <label><input type="checkbox"> Mark as Done</label>
